# %% [markdown]
# ### Import dependencies

# %%
# Dependencies and Setup
import os
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# ### Import Suicide rate and financial indicators for several years

# %%
# Specify CSV file containing master data
# Data Source: 
# https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016

master_file = os.path.join(".","Data/master.csv")

# Import CSV file as Dataframe
master_df = pd.read_csv(master_file)
master_df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %% [markdown]
# ### Add ISO 3 Codes to country names and clean up (makes merging alot easier later on!)

# %%
# Use REST API to collect ISO3code listing for all countries
code_url = "https://restcountries.eu/rest/v2/all"

# Make JSON request to Rest Countries API
country_data = requests.get(code_url).json()

# Peek JSON formatted data
print(json.dumps(country_data,indent=4, sort_keys=True))
# Out:
# [
#     {
#         "alpha2Code": "AF",
#         "alpha3Code": "AFG",
#         "altSpellings": [
#             "AF",
#             "Af\u0121\u0101nist\u0101n"
#         ],
#         "area": 652230.0,
#         "borders": [
#             "IRN",
#             "PAK",
#             "TKM",
#             "UZB",
#             "TJK",
#             "CHN"
#         ],
#         "callingCodes": [
#             "93"
#         ],
#         "capital": "Kabul",
#         "cioc": "AFG",
#         "currencies": [
#             {
#                 "code": "AFN",
#                 "name": "Afghan afghani",
#                 "symbol": "\u060b"
#             }
#         ],
#         "demonym": "Afghan",
#         "flag": "https://restcountries.eu/data/afg.svg",
#         "gini": 27.8,
#         "languages": [
#             {
#                 "iso639_1": "ps",
#                 "iso639_2": "pus",
#                 "name": "Pashto",
#                 "nativeName": "\u067e\u069a\u062a\u0648"
#             },
#             {
#                 "iso639_1": "uz",
#                 "iso639_2": "uzb",
#                 "name": "Uzbek",
#                 "nativeName": "O\u02bbzbek"
#             },
#             {
#                 "iso639_1": "tk",
#                 "iso639_2": "tuk",
#                 "name": "Turkmen",
#                 "nativeName": "T\u00fcrkmen"
#             }
#         ],
#         "latlng": [
#             33.0,
#             65.0
#         ],
#         "name": "Afghanistan",
#         "nativeName": "\u0627\u0641\u063a\u0627\u0646\u0633\u062a\u0627\u0646",
#         "numericCode": "004",
#         "population": 27657145,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "SAARC",
#                 "name": "South Asian Association for Regional Cooperation",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Southern Asia",
#         "timezones": [
#             "UTC+04:30"
#         ],
#         "topLevelDomain": [
#             ".af"
#         ],
#         "translations": {
#             "br": "Afeganist\u00e3o",
#             "de": "Afghanistan",
#             "es": "Afganist\u00e1n",
#             "fa": "\u0627\u0641\u063a\u0627\u0646\u0633\u062a\u0627\u0646",
#             "fr": "Afghanistan",
#             "hr": "Afganistan",
#             "it": "Afghanistan",
#             "ja": "\u30a2\u30d5\u30ac\u30cb\u30b9\u30bf\u30f3",
#             "nl": "Afghanistan",
#             "pt": "Afeganist\u00e3o"
#         }
#     },
#     {
#         "alpha2Code": "AX",
#         "alpha3Code": "ALA",
#         "altSpellings": [
#             "AX",
#             "Aaland",
#             "Aland",
#             "Ahvenanmaa"
#         ],
#         "area": 1580.0,
#         "borders": [],
#         "callingCodes": [
#             "358"
#         ],
#         "capital": "Mariehamn",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "\u00c5landish",
#         "flag": "https://restcountries.eu/data/ala.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "sv",
#                 "iso639_2": "swe",
#                 "name": "Swedish",
#                 "nativeName": "svenska"
#             }
#         ],
#         "latlng": [
#             60.116667,
#             19.9
#         ],
#         "name": "\u00c5land Islands",
#         "nativeName": "\u00c5land",
#         "numericCode": "248",
#         "population": 28875,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EU",
#                 "name": "European Union",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Northern Europe",
#         "timezones": [
#             "UTC+02:00"
#         ],
#         "topLevelDomain": [
#             ".ax"
#         ],
#         "translations": {
#             "br": "Ilhas de Aland",
#             "de": "\u00c5land",
#             "es": "Alandia",
#             "fa": "\u062c\u0632\u0627\u06cc\u0631 \u0627\u0644\u0646\u062f",
#             "fr": "\u00c5land",
#             "hr": "\u00c5landski otoci",
#             "it": "Isole Aland",
#             "ja": "\u30aa\u30fc\u30e9\u30f3\u30c9\u8af8\u5cf6",
#             "nl": "\u00c5landeilanden",
#             "pt": "Ilhas de Aland"
#         }
#     },
#     {
#         "alpha2Code": "AL",
#         "alpha3Code": "ALB",
#         "altSpellings": [
#             "AL",
#             "Shqip\u00ebri",
#             "Shqip\u00ebria",
#             "Shqipnia"
#         ],
#         "area": 28748.0,
#         "borders": [
#             "MNE",
#             "GRC",
#             "MKD",
#             "KOS"
#         ],
#         "callingCodes": [
#             "355"
#         ],
#         "capital": "Tirana",
#         "cioc": "ALB",
#         "currencies": [
#             {
#                 "code": "ALL",
#                 "name": "Albanian lek",
#                 "symbol": "L"
#             }
#         ],
#         "demonym": "Albanian",
#         "flag": "https://restcountries.eu/data/alb.svg",
#         "gini": 34.5,
#         "languages": [
#             {
#                 "iso639_1": "sq",
#                 "iso639_2": "sqi",
#                 "name": "Albanian",
#                 "nativeName": "Shqip"
#             }
#         ],
#         "latlng": [
#             41.0,
#             20.0
#         ],
#         "name": "Albania",
#         "nativeName": "Shqip\u00ebria",
#         "numericCode": "008",
#         "population": 2886026,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "CEFTA",
#                 "name": "Central European Free Trade Agreement",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Southern Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".al"
#         ],
#         "translations": {
#             "br": "Alb\u00e2nia",
#             "de": "Albanien",
#             "es": "Albania",
#             "fa": "\u0622\u0644\u0628\u0627\u0646\u06cc",
#             "fr": "Albanie",
#             "hr": "Albanija",
#             "it": "Albania",
#             "ja": "\u30a2\u30eb\u30d0\u30cb\u30a2",
#             "nl": "Albani\u00eb",
#             "pt": "Alb\u00e2nia"
#         }
#     },
#     {
#         "alpha2Code": "DZ",
#         "alpha3Code": "DZA",
#         "altSpellings": [
#             "DZ",
#             "Dzayer",
#             "Alg\u00e9rie"
#         ],
#         "area": 2381741.0,
#         "borders": [
#             "TUN",
#             "LBY",
#             "NER",
#             "ESH",
#             "MRT",
#             "MLI",
#             "MAR"
#         ],
#         "callingCodes": [
#             "213"
#         ],
#         "capital": "Algiers",
#         "cioc": "ALG",
#         "currencies": [
#             {
#                 "code": "DZD",
#                 "name": "Algerian dinar",
#                 "symbol": "\u062f.\u062c"
#             }
#         ],
#         "demonym": "Algerian",
#         "flag": "https://restcountries.eu/data/dza.svg",
#         "gini": 35.3,
#         "languages": [
#             {
#                 "iso639_1": "ar",
#                 "iso639_2": "ara",
#                 "name": "Arabic",
#                 "nativeName": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             }
#         ],
#         "latlng": [
#             28.0,
#             3.0
#         ],
#         "name": "Algeria",
#         "nativeName": "\u0627\u0644\u062c\u0632\u0627\u0626\u0631",
#         "numericCode": "012",
#         "population": 40400000,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             },
#             {
#                 "acronym": "AL",
#                 "name": "Arab League",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u062f\u0648\u0644 \u0627\u0644\u0639\u0631\u0628\u064a\u0629",
#                     "J\u0101mi\u02bbat ad-Duwal al-\u02bbArab\u012byah",
#                     "League of Arab States"
#                 ]
#             }
#         ],
#         "subregion": "Northern Africa",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".dz"
#         ],
#         "translations": {
#             "br": "Arg\u00e9lia",
#             "de": "Algerien",
#             "es": "Argelia",
#             "fa": "\u0627\u0644\u062c\u0632\u0627\u06cc\u0631",
#             "fr": "Alg\u00e9rie",
#             "hr": "Al\u017eir",
#             "it": "Algeria",
#             "ja": "\u30a2\u30eb\u30b8\u30a7\u30ea\u30a2",
#             "nl": "Algerije",
#             "pt": "Arg\u00e9lia"
#         }
#     },
#     {
#         "alpha2Code": "AS",
#         "alpha3Code": "ASM",
#         "altSpellings": [
#             "AS",
#             "Amerika S\u0101moa",
#             "Amelika S\u0101moa",
#             "S\u0101moa Amelika"
#         ],
#         "area": 199.0,
#         "borders": [],
#         "callingCodes": [
#             "1684"
#         ],
#         "capital": "Pago Pago",
#         "cioc": "ASA",
#         "currencies": [
#             {
#                 "code": "USD",
#                 "name": "United State Dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "American Samoan",
#         "flag": "https://restcountries.eu/data/asm.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "sm",
#                 "iso639_2": "smo",
#                 "name": "Samoan",
#                 "nativeName": "gagana fa'a Samoa"
#             }
#         ],
#         "latlng": [
#             -14.33333333,
#             -170.0
#         ],
#         "name": "American Samoa",
#         "nativeName": "American Samoa",
#         "numericCode": "016",
#         "population": 57100,
#         "region": "Oceania",
#         "regionalBlocs": [],
#         "subregion": "Polynesia",
#         "timezones": [
#             "UTC-11:00"
#         ],
#         "topLevelDomain": [
#             ".as"
#         ],
#         "translations": {
#             "br": "Samoa Americana",
#             "de": "Amerikanisch-Samoa",
#             "es": "Samoa Americana",
#             "fa": "\u0633\u0627\u0645\u0648\u0622\u06cc \u0622\u0645\u0631\u06cc\u06a9\u0627",
#             "fr": "Samoa am\u00e9ricaines",
#             "hr": "Ameri\u010dka Samoa",
#             "it": "Samoa Americane",
#             "ja": "\u30a2\u30e1\u30ea\u30ab\u9818\u30b5\u30e2\u30a2",
#             "nl": "Amerikaans Samoa",
#             "pt": "Samoa Americana"
#         }
#     },
#     {
#         "alpha2Code": "AD",
#         "alpha3Code": "AND",
#         "altSpellings": [
#             "AD",
#             "Principality of Andorra",
#             "Principat d'Andorra"
#         ],
#         "area": 468.0,
#         "borders": [
#             "FRA",
#             "ESP"
#         ],
#         "callingCodes": [
#             "376"
#         ],
#         "capital": "Andorra la Vella",
#         "cioc": "AND",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "Andorran",
#         "flag": "https://restcountries.eu/data/and.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "ca",
#                 "iso639_2": "cat",
#                 "name": "Catalan",
#                 "nativeName": "catal\u00e0"
#             }
#         ],
#         "latlng": [
#             42.5,
#             1.5
#         ],
#         "name": "Andorra",
#         "nativeName": "Andorra",
#         "numericCode": "020",
#         "population": 78014,
#         "region": "Europe",
#         "regionalBlocs": [],
#         "subregion": "Southern Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".ad"
#         ],
#         "translations": {
#             "br": "Andorra",
#             "de": "Andorra",
#             "es": "Andorra",
#             "fa": "\u0622\u0646\u062f\u0648\u0631\u0627",
#             "fr": "Andorre",
#             "hr": "Andora",
#             "it": "Andorra",
#             "ja": "\u30a2\u30f3\u30c9\u30e9",
#             "nl": "Andorra",
#             "pt": "Andorra"
#         }
#     },
#     {
#         "alpha2Code": "AO",
#         "alpha3Code": "AGO",
#         "altSpellings": [
#             "AO",
#             "Rep\u00fablica de Angola",
#             "\u0281\u025bpublika de an'\u0261\u0254la"
#         ],
#         "area": 1246700.0,
#         "borders": [
#             "COG",
#             "COD",
#             "ZMB",
#             "NAM"
#         ],
#         "callingCodes": [
#             "244"
#         ],
#         "capital": "Luanda",
#         "cioc": "ANG",
#         "currencies": [
#             {
#                 "code": "AOA",
#                 "name": "Angolan kwanza",
#                 "symbol": "Kz"
#             }
#         ],
#         "demonym": "Angolan",
#         "flag": "https://restcountries.eu/data/ago.svg",
#         "gini": 58.6,
#         "languages": [
#             {
#                 "iso639_1": "pt",
#                 "iso639_2": "por",
#                 "name": "Portuguese",
#                 "nativeName": "Portugu\u00eas"
#             }
#         ],
#         "latlng": [
#             -12.5,
#             18.5
#         ],
#         "name": "Angola",
#         "nativeName": "Angola",
#         "numericCode": "024",
#         "population": 25868000,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Middle Africa",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".ao"
#         ],
#         "translations": {
#             "br": "Angola",
#             "de": "Angola",
#             "es": "Angola",
#             "fa": "\u0622\u0646\u06af\u0648\u0644\u0627",
#             "fr": "Angola",
#             "hr": "Angola",
#             "it": "Angola",
#             "ja": "\u30a2\u30f3\u30b4\u30e9",
#             "nl": "Angola",
#             "pt": "Angola"
#         }
#     },
#     {
#         "alpha2Code": "AI",
#         "alpha3Code": "AIA",
#         "altSpellings": [
#             "AI"
#         ],
#         "area": 91.0,
#         "borders": [],
#         "callingCodes": [
#             "1264"
#         ],
#         "capital": "The Valley",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "XCD",
#                 "name": "East Caribbean dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Anguillian",
#         "flag": "https://restcountries.eu/data/aia.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             18.25,
#             -63.16666666
#         ],
#         "name": "Anguilla",
#         "nativeName": "Anguilla",
#         "numericCode": "660",
#         "population": 13452,
#         "region": "Americas",
#         "regionalBlocs": [],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".ai"
#         ],
#         "translations": {
#             "br": "Anguila",
#             "de": "Anguilla",
#             "es": "Anguilla",
#             "fa": "\u0622\u0646\u06af\u0648\u06cc\u0644\u0627",
#             "fr": "Anguilla",
#             "hr": "Angvila",
#             "it": "Anguilla",
#             "ja": "\u30a2\u30f3\u30ae\u30e9",
#             "nl": "Anguilla",
#             "pt": "Anguila"
#         }
#     },
#     {
#         "alpha2Code": "AQ",
#         "alpha3Code": "ATA",
#         "altSpellings": [],
#         "area": 14000000.0,
#         "borders": [],
#         "callingCodes": [
#             "672"
#         ],
#         "capital": "",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "AUD",
#                 "name": "Australian dollar",
#                 "symbol": "$"
#             },
#             {
#                 "code": "GBP",
#                 "name": "British pound",
#                 "symbol": "\u00a3"
#             }
#         ],
#         "demonym": "",
#         "flag": "https://restcountries.eu/data/ata.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "ru",
#                 "iso639_2": "rus",
#                 "name": "Russian",
#                 "nativeName": "\u0420\u0443\u0441\u0441\u043a\u0438\u0439"
#             }
#         ],
#         "latlng": [
#             -74.65,
#             4.48
#         ],
#         "name": "Antarctica",
#         "nativeName": "Antarctica",
#         "numericCode": "010",
#         "population": 1000,
#         "region": "Polar",
#         "regionalBlocs": [],
#         "subregion": "",
#         "timezones": [
#             "UTC-03:00",
#             "UTC+03:00",
#             "UTC+05:00",
#             "UTC+06:00",
#             "UTC+07:00",
#             "UTC+08:00",
#             "UTC+10:00",
#             "UTC+12:00"
#         ],
#         "topLevelDomain": [
#             ".aq"
#         ],
#         "translations": {
#             "br": "Ant\u00e1rtida",
#             "de": "Antarktika",
#             "es": "Ant\u00e1rtida",
#             "fa": "\u062c\u0646\u0648\u0628\u06af\u0627\u0646",
#             "fr": "Antarctique",
#             "hr": "Antarktika",
#             "it": "Antartide",
#             "ja": "\u5357\u6975\u5927\u9678",
#             "nl": "Antarctica",
#             "pt": "Ant\u00e1rctida"
#         }
#     },
#     {
#         "alpha2Code": "AG",
#         "alpha3Code": "ATG",
#         "altSpellings": [
#             "AG"
#         ],
#         "area": 442.0,
#         "borders": [],
#         "callingCodes": [
#             "1268"
#         ],
#         "capital": "Saint John's",
#         "cioc": "ANT",
#         "currencies": [
#             {
#                 "code": "XCD",
#                 "name": "East Caribbean dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Antiguan, Barbudan",
#         "flag": "https://restcountries.eu/data/atg.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             17.05,
#             -61.8
#         ],
#         "name": "Antigua and Barbuda",
#         "nativeName": "Antigua and Barbuda",
#         "numericCode": "028",
#         "population": 86295,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             }
#         ],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".ag"
#         ],
#         "translations": {
#             "br": "Ant\u00edgua e Barbuda",
#             "de": "Antigua und Barbuda",
#             "es": "Antigua y Barbuda",
#             "fa": "\u0622\u0646\u062a\u06cc\u06af\u0648\u0627 \u0648 \u0628\u0627\u0631\u0628\u0648\u062f\u0627",
#             "fr": "Antigua-et-Barbuda",
#             "hr": "Antigva i Barbuda",
#             "it": "Antigua e Barbuda",
#             "ja": "\u30a2\u30f3\u30c6\u30a3\u30b0\u30a2\u30fb\u30d0\u30fc\u30d6\u30fc\u30c0",
#             "nl": "Antigua en Barbuda",
#             "pt": "Ant\u00edgua e Barbuda"
#         }
#     },
#     {
#         "alpha2Code": "AR",
#         "alpha3Code": "ARG",
#         "altSpellings": [
#             "AR",
#             "Argentine Republic",
#             "Rep\u00fablica Argentina"
#         ],
#         "area": 2780400.0,
#         "borders": [
#             "BOL",
#             "BRA",
#             "CHL",
#             "PRY",
#             "URY"
#         ],
#         "callingCodes": [
#             "54"
#         ],
#         "capital": "Buenos Aires",
#         "cioc": "ARG",
#         "currencies": [
#             {
#                 "code": "ARS",
#                 "name": "Argentine peso",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Argentinean",
#         "flag": "https://restcountries.eu/data/arg.svg",
#         "gini": 44.5,
#         "languages": [
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             },
#             {
#                 "iso639_1": "gn",
#                 "iso639_2": "grn",
#                 "name": "Guaran\u00ed",
#                 "nativeName": "Ava\u00f1e'\u1ebd"
#             }
#         ],
#         "latlng": [
#             -34.0,
#             -64.0
#         ],
#         "name": "Argentina",
#         "nativeName": "Argentina",
#         "numericCode": "032",
#         "population": 43590400,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "USAN",
#                 "name": "Union of South American Nations",
#                 "otherAcronyms": [
#                     "UNASUR",
#                     "UNASUL",
#                     "UZAN"
#                 ],
#                 "otherNames": [
#                     "Uni\u00f3n de Naciones Suramericanas",
#                     "Uni\u00e3o de Na\u00e7\u00f5es Sul-Americanas",
#                     "Unie van Zuid-Amerikaanse Naties",
#                     "South American Union"
#                 ]
#             }
#         ],
#         "subregion": "South America",
#         "timezones": [
#             "UTC-03:00"
#         ],
#         "topLevelDomain": [
#             ".ar"
#         ],
#         "translations": {
#             "br": "Argentina",
#             "de": "Argentinien",
#             "es": "Argentina",
#             "fa": "\u0622\u0631\u0698\u0627\u0646\u062a\u06cc\u0646",
#             "fr": "Argentine",
#             "hr": "Argentina",
#             "it": "Argentina",
#             "ja": "\u30a2\u30eb\u30bc\u30f3\u30c1\u30f3",
#             "nl": "Argentini\u00eb",
#             "pt": "Argentina"
#         }
#     },
#     {
#         "alpha2Code": "AM",
#         "alpha3Code": "ARM",
#         "altSpellings": [
#             "AM",
#             "Hayastan",
#             "Republic of Armenia",
#             "\u0540\u0561\u0575\u0561\u057d\u057f\u0561\u0576\u056b \u0540\u0561\u0576\u0580\u0561\u057a\u0565\u057f\u0578\u0582\u0569\u0575\u0578\u0582\u0576"
#         ],
#         "area": 29743.0,
#         "borders": [
#             "AZE",
#             "GEO",
#             "IRN",
#             "TUR"
#         ],
#         "callingCodes": [
#             "374"
#         ],
#         "capital": "Yerevan",
#         "cioc": "ARM",
#         "currencies": [
#             {
#                 "code": "AMD",
#                 "name": "Armenian dram",
#                 "symbol": null
#             }
#         ],
#         "demonym": "Armenian",
#         "flag": "https://restcountries.eu/data/arm.svg",
#         "gini": 30.9,
#         "languages": [
#             {
#                 "iso639_1": "hy",
#                 "iso639_2": "hye",
#                 "name": "Armenian",
#                 "nativeName": "\u0540\u0561\u0575\u0565\u0580\u0565\u0576"
#             },
#             {
#                 "iso639_1": "ru",
#                 "iso639_2": "rus",
#                 "name": "Russian",
#                 "nativeName": "\u0420\u0443\u0441\u0441\u043a\u0438\u0439"
#             }
#         ],
#         "latlng": [
#             40.0,
#             45.0
#         ],
#         "name": "Armenia",
#         "nativeName": "\u0540\u0561\u0575\u0561\u057d\u057f\u0561\u0576",
#         "numericCode": "051",
#         "population": 2994400,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "EEU",
#                 "name": "Eurasian Economic Union",
#                 "otherAcronyms": [
#                     "EAEU"
#                 ],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+04:00"
#         ],
#         "topLevelDomain": [
#             ".am"
#         ],
#         "translations": {
#             "br": "Arm\u00eania",
#             "de": "Armenien",
#             "es": "Armenia",
#             "fa": "\u0627\u0631\u0645\u0646\u0633\u062a\u0627\u0646",
#             "fr": "Arm\u00e9nie",
#             "hr": "Armenija",
#             "it": "Armenia",
#             "ja": "\u30a2\u30eb\u30e1\u30cb\u30a2",
#             "nl": "Armeni\u00eb",
#             "pt": "Arm\u00e9nia"
#         }
#     },
#     {
#         "alpha2Code": "AW",
#         "alpha3Code": "ABW",
#         "altSpellings": [
#             "AW"
#         ],
#         "area": 180.0,
#         "borders": [],
#         "callingCodes": [
#             "297"
#         ],
#         "capital": "Oranjestad",
#         "cioc": "ARU",
#         "currencies": [
#             {
#                 "code": "AWG",
#                 "name": "Aruban florin",
#                 "symbol": "\u0192"
#             }
#         ],
#         "demonym": "Aruban",
#         "flag": "https://restcountries.eu/data/abw.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "nl",
#                 "iso639_2": "nld",
#                 "name": "Dutch",
#                 "nativeName": "Nederlands"
#             },
#             {
#                 "iso639_1": "pa",
#                 "iso639_2": "pan",
#                 "name": "(Eastern) Punjabi",
#                 "nativeName": "\u0a2a\u0a70\u0a1c\u0a3e\u0a2c\u0a40"
#             }
#         ],
#         "latlng": [
#             12.5,
#             -69.96666666
#         ],
#         "name": "Aruba",
#         "nativeName": "Aruba",
#         "numericCode": "533",
#         "population": 107394,
#         "region": "Americas",
#         "regionalBlocs": [],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".aw"
#         ],
#         "translations": {
#             "br": "Aruba",
#             "de": "Aruba",
#             "es": "Aruba",
#             "fa": "\u0622\u0631\u0648\u0628\u0627",
#             "fr": "Aruba",
#             "hr": "Aruba",
#             "it": "Aruba",
#             "ja": "\u30a2\u30eb\u30d0",
#             "nl": "Aruba",
#             "pt": "Aruba"
#         }
#     },
#     {
#         "alpha2Code": "AU",
#         "alpha3Code": "AUS",
#         "altSpellings": [
#             "AU"
#         ],
#         "area": 7692024.0,
#         "borders": [],
#         "callingCodes": [
#             "61"
#         ],
#         "capital": "Canberra",
#         "cioc": "AUS",
#         "currencies": [
#             {
#                 "code": "AUD",
#                 "name": "Australian dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Australian",
#         "flag": "https://restcountries.eu/data/aus.svg",
#         "gini": 30.5,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             -27.0,
#             133.0
#         ],
#         "name": "Australia",
#         "nativeName": "Australia",
#         "numericCode": "036",
#         "population": 24117360,
#         "region": "Oceania",
#         "regionalBlocs": [],
#         "subregion": "Australia and New Zealand",
#         "timezones": [
#             "UTC+05:00",
#             "UTC+06:30",
#             "UTC+07:00",
#             "UTC+08:00",
#             "UTC+09:30",
#             "UTC+10:00",
#             "UTC+10:30",
#             "UTC+11:30"
#         ],
#         "topLevelDomain": [
#             ".au"
#         ],
#         "translations": {
#             "br": "Austr\u00e1lia",
#             "de": "Australien",
#             "es": "Australia",
#             "fa": "\u0627\u0633\u062a\u0631\u0627\u0644\u06cc\u0627",
#             "fr": "Australie",
#             "hr": "Australija",
#             "it": "Australia",
#             "ja": "\u30aa\u30fc\u30b9\u30c8\u30e9\u30ea\u30a2",
#             "nl": "Australi\u00eb",
#             "pt": "Austr\u00e1lia"
#         }
#     },
#     {
#         "alpha2Code": "AT",
#         "alpha3Code": "AUT",
#         "altSpellings": [
#             "AT",
#             "\u00d6sterreich",
#             "Osterreich",
#             "Oesterreich"
#         ],
#         "area": 83871.0,
#         "borders": [
#             "CZE",
#             "DEU",
#             "HUN",
#             "ITA",
#             "LIE",
#             "SVK",
#             "SVN",
#             "CHE"
#         ],
#         "callingCodes": [
#             "43"
#         ],
#         "capital": "Vienna",
#         "cioc": "AUT",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "Austrian",
#         "flag": "https://restcountries.eu/data/aut.svg",
#         "gini": 26.0,
#         "languages": [
#             {
#                 "iso639_1": "de",
#                 "iso639_2": "deu",
#                 "name": "German",
#                 "nativeName": "Deutsch"
#             }
#         ],
#         "latlng": [
#             47.33333333,
#             13.33333333
#         ],
#         "name": "Austria",
#         "nativeName": "\u00d6sterreich",
#         "numericCode": "040",
#         "population": 8725931,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EU",
#                 "name": "European Union",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Western Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".at"
#         ],
#         "translations": {
#             "br": "\u00e1ustria",
#             "de": "\u00d6sterreich",
#             "es": "Austria",
#             "fa": "\u0627\u062a\u0631\u06cc\u0634",
#             "fr": "Autriche",
#             "hr": "Austrija",
#             "it": "Austria",
#             "ja": "\u30aa\u30fc\u30b9\u30c8\u30ea\u30a2",
#             "nl": "Oostenrijk",
#             "pt": "\u00e1ustria"
#         }
#     },
#     {
#         "alpha2Code": "AZ",
#         "alpha3Code": "AZE",
#         "altSpellings": [
#             "AZ",
#             "Republic of Azerbaijan",
#             "Az\u0259rbaycan Respublikas\u0131"
#         ],
#         "area": 86600.0,
#         "borders": [
#             "ARM",
#             "GEO",
#             "IRN",
#             "RUS",
#             "TUR"
#         ],
#         "callingCodes": [
#             "994"
#         ],
#         "capital": "Baku",
#         "cioc": "AZE",
#         "currencies": [
#             {
#                 "code": "AZN",
#                 "name": "Azerbaijani manat",
#                 "symbol": null
#             }
#         ],
#         "demonym": "Azerbaijani",
#         "flag": "https://restcountries.eu/data/aze.svg",
#         "gini": 33.7,
#         "languages": [
#             {
#                 "iso639_1": "az",
#                 "iso639_2": "aze",
#                 "name": "Azerbaijani",
#                 "nativeName": "az\u0259rbaycan dili"
#             }
#         ],
#         "latlng": [
#             40.5,
#             47.5
#         ],
#         "name": "Azerbaijan",
#         "nativeName": "Az\u0259rbaycan",
#         "numericCode": "031",
#         "population": 9730500,
#         "region": "Asia",
#         "regionalBlocs": [],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+04:00"
#         ],
#         "topLevelDomain": [
#             ".az"
#         ],
#         "translations": {
#             "br": "Azerbaij\u00e3o",
#             "de": "Aserbaidschan",
#             "es": "Azerbaiy\u00e1n",
#             "fa": "\u0622\u0630\u0631\u0628\u0627\u06cc\u062c\u0627\u0646",
#             "fr": "Azerba\u00efdjan",
#             "hr": "Azerbajd\u017ean",
#             "it": "Azerbaijan",
#             "ja": "\u30a2\u30bc\u30eb\u30d0\u30a4\u30b8\u30e3\u30f3",
#             "nl": "Azerbeidzjan",
#             "pt": "Azerbaij\u00e3o"
#         }
#     },
#     {
#         "alpha2Code": "BS",
#         "alpha3Code": "BHS",
#         "altSpellings": [
#             "BS",
#             "Commonwealth of the Bahamas"
#         ],
#         "area": 13943.0,
#         "borders": [],
#         "callingCodes": [
#             "1242"
#         ],
#         "capital": "Nassau",
#         "cioc": "BAH",
#         "currencies": [
#             {
#                 "code": "BSD",
#                 "name": "Bahamian dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Bahamian",
#         "flag": "https://restcountries.eu/data/bhs.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             24.25,
#             -76.0
#         ],
#         "name": "Bahamas",
#         "nativeName": "Bahamas",
#         "numericCode": "044",
#         "population": 378040,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             }
#         ],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-05:00"
#         ],
#         "topLevelDomain": [
#             ".bs"
#         ],
#         "translations": {
#             "br": "Bahamas",
#             "de": "Bahamas",
#             "es": "Bahamas",
#             "fa": "\u0628\u0627\u0647\u0627\u0645\u0627",
#             "fr": "Bahamas",
#             "hr": "Bahami",
#             "it": "Bahamas",
#             "ja": "\u30d0\u30cf\u30de",
#             "nl": "Bahama\u2019s",
#             "pt": "Baamas"
#         }
#     },
#     {
#         "alpha2Code": "BH",
#         "alpha3Code": "BHR",
#         "altSpellings": [
#             "BH",
#             "Kingdom of Bahrain",
#             "Mamlakat al-Ba\u1e25rayn"
#         ],
#         "area": 765.0,
#         "borders": [],
#         "callingCodes": [
#             "973"
#         ],
#         "capital": "Manama",
#         "cioc": "BRN",
#         "currencies": [
#             {
#                 "code": "BHD",
#                 "name": "Bahraini dinar",
#                 "symbol": ".\u062f.\u0628"
#             }
#         ],
#         "demonym": "Bahraini",
#         "flag": "https://restcountries.eu/data/bhr.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "ar",
#                 "iso639_2": "ara",
#                 "name": "Arabic",
#                 "nativeName": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             }
#         ],
#         "latlng": [
#             26.0,
#             50.55
#         ],
#         "name": "Bahrain",
#         "nativeName": "\u200f\u0627\u0644\u0628\u062d\u0631\u064a\u0646",
#         "numericCode": "048",
#         "population": 1404900,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "AL",
#                 "name": "Arab League",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u062f\u0648\u0644 \u0627\u0644\u0639\u0631\u0628\u064a\u0629",
#                     "J\u0101mi\u02bbat ad-Duwal al-\u02bbArab\u012byah",
#                     "League of Arab States"
#                 ]
#             }
#         ],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+03:00"
#         ],
#         "topLevelDomain": [
#             ".bh"
#         ],
#         "translations": {
#             "br": "Bahrein",
#             "de": "Bahrain",
#             "es": "Bahrein",
#             "fa": "\u0628\u062d\u0631\u06cc\u0646",
#             "fr": "Bahre\u00efn",
#             "hr": "Bahrein",
#             "it": "Bahrein",
#             "ja": "\u30d0\u30fc\u30ec\u30fc\u30f3",
#             "nl": "Bahrein",
#             "pt": "Bar\u00e9m"
#         }
#     },
#     {
#         "alpha2Code": "BD",
#         "alpha3Code": "BGD",
#         "altSpellings": [
#             "BD",
#             "People's Republic of Bangladesh",
#             "G\u00f4n\u00f4pr\u00f4jat\u00f4ntri Bangladesh"
#         ],
#         "area": 147570.0,
#         "borders": [
#             "MMR",
#             "IND"
#         ],
#         "callingCodes": [
#             "880"
#         ],
#         "capital": "Dhaka",
#         "cioc": "BAN",
#         "currencies": [
#             {
#                 "code": "BDT",
#                 "name": "Bangladeshi taka",
#                 "symbol": "\u09f3"
#             }
#         ],
#         "demonym": "Bangladeshi",
#         "flag": "https://restcountries.eu/data/bgd.svg",
#         "gini": 32.1,
#         "languages": [
#             {
#                 "iso639_1": "bn",
#                 "iso639_2": "ben",
#                 "name": "Bengali",
#                 "nativeName": "\u09ac\u09be\u0982\u09b2\u09be"
#             }
#         ],
#         "latlng": [
#             24.0,
#             90.0
#         ],
#         "name": "Bangladesh",
#         "nativeName": "Bangladesh",
#         "numericCode": "050",
#         "population": 161006790,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "SAARC",
#                 "name": "South Asian Association for Regional Cooperation",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Southern Asia",
#         "timezones": [
#             "UTC+06:00"
#         ],
#         "topLevelDomain": [
#             ".bd"
#         ],
#         "translations": {
#             "br": "Bangladesh",
#             "de": "Bangladesch",
#             "es": "Bangladesh",
#             "fa": "\u0628\u0646\u06af\u0644\u0627\u062f\u0634",
#             "fr": "Bangladesh",
#             "hr": "Banglade\u0161",
#             "it": "Bangladesh",
#             "ja": "\u30d0\u30f3\u30b0\u30e9\u30c7\u30b7\u30e5",
#             "nl": "Bangladesh",
#             "pt": "Bangladeche"
#         }
#     },
#     {
#         "alpha2Code": "BB",
#         "alpha3Code": "BRB",
#         "altSpellings": [
#             "BB"
#         ],
#         "area": 430.0,
#         "borders": [],
#         "callingCodes": [
#             "1246"
#         ],
#         "capital": "Bridgetown",
#         "cioc": "BAR",
#         "currencies": [
#             {
#                 "code": "BBD",
#                 "name": "Barbadian dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Barbadian",
#         "flag": "https://restcountries.eu/data/brb.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             13.16666666,
#             -59.53333333
#         ],
#         "name": "Barbados",
#         "nativeName": "Barbados",
#         "numericCode": "052",
#         "population": 285000,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             }
#         ],
#         "subregion": "Caribbean",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".bb"
#         ],
#         "translations": {
#             "br": "Barbados",
#             "de": "Barbados",
#             "es": "Barbados",
#             "fa": "\u0628\u0627\u0631\u0628\u0627\u062f\u0648\u0633",
#             "fr": "Barbade",
#             "hr": "Barbados",
#             "it": "Barbados",
#             "ja": "\u30d0\u30eb\u30d0\u30c9\u30b9",
#             "nl": "Barbados",
#             "pt": "Barbados"
#         }
#     },
#     {
#         "alpha2Code": "BY",
#         "alpha3Code": "BLR",
#         "altSpellings": [
#             "BY",
#             "Bielaru\u015b",
#             "Republic of Belarus",
#             "\u0411\u0435\u043b\u043e\u0440\u0443\u0441\u0441\u0438\u044f",
#             "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u0411\u0435\u043b\u0430\u0440\u0443\u0441\u044c",
#             "Belorussiya",
#             "Respublika Belarus\u2019"
#         ],
#         "area": 207600.0,
#         "borders": [
#             "LVA",
#             "LTU",
#             "POL",
#             "RUS",
#             "UKR"
#         ],
#         "callingCodes": [
#             "375"
#         ],
#         "capital": "Minsk",
#         "cioc": "BLR",
#         "currencies": [
#             {
#                 "code": "BYN",
#                 "name": "New Belarusian ruble",
#                 "symbol": "Br"
#             },
#             {
#                 "code": "BYR",
#                 "name": "Old Belarusian ruble",
#                 "symbol": "Br"
#             }
#         ],
#         "demonym": "Belarusian",
#         "flag": "https://restcountries.eu/data/blr.svg",
#         "gini": 26.5,
#         "languages": [
#             {
#                 "iso639_1": "be",
#                 "iso639_2": "bel",
#                 "name": "Belarusian",
#                 "nativeName": "\u0431\u0435\u043b\u0430\u0440\u0443\u0441\u043a\u0430\u044f \u043c\u043e\u0432\u0430"
#             },
#             {
#                 "iso639_1": "ru",
#                 "iso639_2": "rus",
#                 "name": "Russian",
#                 "nativeName": "\u0420\u0443\u0441\u0441\u043a\u0438\u0439"
#             }
#         ],
#         "latlng": [
#             53.0,
#             28.0
#         ],
#         "name": "Belarus",
#         "nativeName": "\u0411\u0435\u043b\u0430\u0440\u0443\u0301\u0441\u044c",
#         "numericCode": "112",
#         "population": 9498700,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EEU",
#                 "name": "Eurasian Economic Union",
#                 "otherAcronyms": [
#                     "EAEU"
#                 ],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Eastern Europe",
#         "timezones": [
#             "UTC+03:00"
#         ],
#         "topLevelDomain": [
#             ".by"
#         ],
#         "translations": {
#             "br": "Bielorr\u00fassia",
#             "de": "Wei\u00dfrussland",
#             "es": "Bielorrusia",
#             "fa": "\u0628\u0644\u0627\u0631\u0648\u0633",
#             "fr": "Bi\u00e9lorussie",
#             "hr": "Bjelorusija",
#             "it": "Bielorussia",
#             "ja": "\u30d9\u30e9\u30eb\u30fc\u30b7",
#             "nl": "Wit-Rusland",
#             "pt": "Bielorr\u00fassia"
#         }
#     },
#     {
#         "alpha2Code": "BE",
#         "alpha3Code": "BEL",
#         "altSpellings": [
#             "BE",
#             "Belgi\u00eb",
#             "Belgie",
#             "Belgien",
#             "Belgique",
#             "Kingdom of Belgium",
#             "Koninkrijk Belgi\u00eb",
#             "Royaume de Belgique",
#             "K\u00f6nigreich Belgien"
#         ],
#         "area": 30528.0,
#         "borders": [
#             "FRA",
#             "DEU",
#             "LUX",
#             "NLD"
#         ],
#         "callingCodes": [
#             "32"
#         ],
#         "capital": "Brussels",
#         "cioc": "BEL",
#         "currencies": [
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             }
#         ],
#         "demonym": "Belgian",
#         "flag": "https://restcountries.eu/data/bel.svg",
#         "gini": 33.0,
#         "languages": [
#             {
#                 "iso639_1": "nl",
#                 "iso639_2": "nld",
#                 "name": "Dutch",
#                 "nativeName": "Nederlands"
#             },
#             {
#                 "iso639_1": "fr",
#                 "iso639_2": "fra",
#                 "name": "French",
#                 "nativeName": "fran\u00e7ais"
#             },
#             {
#                 "iso639_1": "de",
#                 "iso639_2": "deu",
#                 "name": "German",
#                 "nativeName": "Deutsch"
#             }
#         ],
#         "latlng": [
#             50.83333333,
#             4.0
#         ],
#         "name": "Belgium",
#         "nativeName": "Belgi\u00eb",
#         "numericCode": "056",
#         "population": 11319511,
#         "region": "Europe",
#         "regionalBlocs": [
#             {
#                 "acronym": "EU",
#                 "name": "European Union",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "Western Europe",
#         "timezones": [
#             "UTC+01:00"
#         ],
#         "topLevelDomain": [
#             ".be"
#         ],
#         "translations": {
#             "br": "B\u00e9lgica",
#             "de": "Belgien",
#             "es": "B\u00e9lgica",
#             "fa": "\u0628\u0644\u0698\u06cc\u06a9",
#             "fr": "Belgique",
#             "hr": "Belgija",
#             "it": "Belgio",
#             "ja": "\u30d9\u30eb\u30ae\u30fc",
#             "nl": "Belgi\u00eb",
#             "pt": "B\u00e9lgica"
#         }
#     },
#     {
#         "alpha2Code": "BZ",
#         "alpha3Code": "BLZ",
#         "altSpellings": [
#             "BZ"
#         ],
#         "area": 22966.0,
#         "borders": [
#             "GTM",
#             "MEX"
#         ],
#         "callingCodes": [
#             "501"
#         ],
#         "capital": "Belmopan",
#         "cioc": "BIZ",
#         "currencies": [
#             {
#                 "code": "BZD",
#                 "name": "Belize dollar",
#                 "symbol": "$"
#             }
#         ],
#         "demonym": "Belizean",
#         "flag": "https://restcountries.eu/data/blz.svg",
#         "gini": 53.1,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             }
#         ],
#         "latlng": [
#             17.25,
#             -88.75
#         ],
#         "name": "Belize",
#         "nativeName": "Belize",
#         "numericCode": "084",
#         "population": 370300,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "CARICOM",
#                 "name": "Caribbean Community",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "Comunidad del Caribe",
#                     "Communaut\u00e9 Carib\u00e9enne",
#                     "Caribische Gemeenschap"
#                 ]
#             },
#             {
#                 "acronym": "CAIS",
#                 "name": "Central American Integration System",
#                 "otherAcronyms": [
#                     "SICA"
#                 ],
#                 "otherNames": [
#                     "Sistema de la Integraci\u00f3n Centroamericana,"
#                 ]
#             }
#         ],
#         "subregion": "Central America",
#         "timezones": [
#             "UTC-06:00"
#         ],
#         "topLevelDomain": [
#             ".bz"
# ...
#         "flag": "https://restcountries.eu/data/ven.svg",
#         "gini": 44.8,
#         "languages": [
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             }
#         ],
#         "latlng": [
#             8.0,
#             -66.0
#         ],
#         "name": "Venezuela (Bolivarian Republic of)",
#         "nativeName": "Venezuela",
#         "numericCode": "862",
#         "population": 31028700,
#         "region": "Americas",
#         "regionalBlocs": [
#             {
#                 "acronym": "USAN",
#                 "name": "Union of South American Nations",
#                 "otherAcronyms": [
#                     "UNASUR",
#                     "UNASUL",
#                     "UZAN"
#                 ],
#                 "otherNames": [
#                     "Uni\u00f3n de Naciones Suramericanas",
#                     "Uni\u00e3o de Na\u00e7\u00f5es Sul-Americanas",
#                     "Unie van Zuid-Amerikaanse Naties",
#                     "South American Union"
#                 ]
#             }
#         ],
#         "subregion": "South America",
#         "timezones": [
#             "UTC-04:00"
#         ],
#         "topLevelDomain": [
#             ".ve"
#         ],
#         "translations": {
#             "br": "Venezuela",
#             "de": "Venezuela",
#             "es": "Venezuela",
#             "fa": "\u0648\u0646\u0632\u0648\u0626\u0644\u0627",
#             "fr": "Venezuela",
#             "hr": "Venezuela",
#             "it": "Venezuela",
#             "ja": "\u30d9\u30cd\u30ba\u30a8\u30e9\u30fb\u30dc\u30ea\u30d0\u30eb\u5171\u548c\u56fd",
#             "nl": "Venezuela",
#             "pt": "Venezuela"
#         }
#     },
#     {
#         "alpha2Code": "VN",
#         "alpha3Code": "VNM",
#         "altSpellings": [
#             "VN",
#             "Socialist Republic of Vietnam",
#             "C\u1ed9ng h\u00f2a X\u00e3 h\u1ed9i ch\u1ee7 ngh\u0129a Vi\u1ec7t Nam"
#         ],
#         "area": 331212.0,
#         "borders": [
#             "KHM",
#             "CHN",
#             "LAO"
#         ],
#         "callingCodes": [
#             "84"
#         ],
#         "capital": "Hanoi",
#         "cioc": "VIE",
#         "currencies": [
#             {
#                 "code": "VND",
#                 "name": "Vietnamese \u0111\u1ed3ng",
#                 "symbol": "\u20ab"
#             }
#         ],
#         "demonym": "Vietnamese",
#         "flag": "https://restcountries.eu/data/vnm.svg",
#         "gini": 35.6,
#         "languages": [
#             {
#                 "iso639_1": "vi",
#                 "iso639_2": "vie",
#                 "name": "Vietnamese",
#                 "nativeName": "Ti\u1ebfng Vi\u1ec7t"
#             }
#         ],
#         "latlng": [
#             16.16666666,
#             107.83333333
#         ],
#         "name": "Viet Nam",
#         "nativeName": "Vi\u1ec7t Nam",
#         "numericCode": "704",
#         "population": 92700000,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "ASEAN",
#                 "name": "Association of Southeast Asian Nations",
#                 "otherAcronyms": [],
#                 "otherNames": []
#             }
#         ],
#         "subregion": "South-Eastern Asia",
#         "timezones": [
#             "UTC+07:00"
#         ],
#         "topLevelDomain": [
#             ".vn"
#         ],
#         "translations": {
#             "br": "Vietn\u00e3",
#             "de": "Vietnam",
#             "es": "Vietnam",
#             "fa": "\u0648\u06cc\u062a\u0646\u0627\u0645",
#             "fr": "Vi\u00eat Nam",
#             "hr": "Vijetnam",
#             "it": "Vietnam",
#             "ja": "\u30d9\u30c8\u30ca\u30e0",
#             "nl": "Vietnam",
#             "pt": "Vietname"
#         }
#     },
#     {
#         "alpha2Code": "WF",
#         "alpha3Code": "WLF",
#         "altSpellings": [
#             "WF",
#             "Territory of the Wallis and Futuna Islands",
#             "Territoire des \u00eeles Wallis et Futuna"
#         ],
#         "area": 142.0,
#         "borders": [],
#         "callingCodes": [
#             "681"
#         ],
#         "capital": "Mata-Utu",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "XPF",
#                 "name": "CFP franc",
#                 "symbol": "Fr"
#             }
#         ],
#         "demonym": "Wallis and Futuna Islander",
#         "flag": "https://restcountries.eu/data/wlf.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "fr",
#                 "iso639_2": "fra",
#                 "name": "French",
#                 "nativeName": "fran\u00e7ais"
#             }
#         ],
#         "latlng": [
#             -13.3,
#             -176.2
#         ],
#         "name": "Wallis and Futuna",
#         "nativeName": "Wallis et Futuna",
#         "numericCode": "876",
#         "population": 11750,
#         "region": "Oceania",
#         "regionalBlocs": [],
#         "subregion": "Polynesia",
#         "timezones": [
#             "UTC+12:00"
#         ],
#         "topLevelDomain": [
#             ".wf"
#         ],
#         "translations": {
#             "br": "Wallis e Futuna",
#             "de": "Wallis und Futuna",
#             "es": "Wallis y Futuna",
#             "fa": "\u0648\u0627\u0644\u06cc\u0633 \u0648 \u0641\u0648\u062a\u0648\u0646\u0627",
#             "fr": "Wallis-et-Futuna",
#             "hr": "Wallis i Fortuna",
#             "it": "Wallis e Futuna",
#             "ja": "\u30a6\u30a9\u30ea\u30b9\u30fb\u30d5\u30c4\u30ca",
#             "nl": "Wallis en Futuna",
#             "pt": "Wallis e Futuna"
#         }
#     },
#     {
#         "alpha2Code": "EH",
#         "alpha3Code": "ESH",
#         "altSpellings": [
#             "EH",
#             "Tane\u1e93roft Tutrimt"
#         ],
#         "area": 266000.0,
#         "borders": [
#             "DZA",
#             "MRT",
#             "MAR"
#         ],
#         "callingCodes": [
#             "212"
#         ],
#         "capital": "El Aai\u00fan",
#         "cioc": "",
#         "currencies": [
#             {
#                 "code": "MAD",
#                 "name": "Moroccan dirham",
#                 "symbol": "\u062f.\u0645."
#             },
#             {
#                 "code": "DZD",
#                 "name": "Algerian dinar",
#                 "symbol": "\u062f.\u062c"
#             }
#         ],
#         "demonym": "Sahrawi",
#         "flag": "https://restcountries.eu/data/esh.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "es",
#                 "iso639_2": "spa",
#                 "name": "Spanish",
#                 "nativeName": "Espa\u00f1ol"
#             }
#         ],
#         "latlng": [
#             24.5,
#             -13.0
#         ],
#         "name": "Western Sahara",
#         "nativeName": "\u0627\u0644\u0635\u062d\u0631\u0627\u0621 \u0627\u0644\u063a\u0631\u0628\u064a\u0629",
#         "numericCode": "732",
#         "population": 510713,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Northern Africa",
#         "timezones": [
#             "UTC+00:00"
#         ],
#         "topLevelDomain": [
#             ".eh"
#         ],
#         "translations": {
#             "br": "Saara Ocidental",
#             "de": "Westsahara",
#             "es": "Sahara Occidental",
#             "fa": "\u062c\u0645\u0647\u0648\u0631\u06cc \u062f\u0645\u0648\u06a9\u0631\u0627\u062a\u06cc\u06a9 \u0639\u0631\u0628\u06cc \u0635\u062d\u0631\u0627",
#             "fr": "Sahara Occidental",
#             "hr": "Zapadna Sahara",
#             "it": "Sahara Occidentale",
#             "ja": "\u897f\u30b5\u30cf\u30e9",
#             "nl": "Westelijke Sahara",
#             "pt": "Saara Ocidental"
#         }
#     },
#     {
#         "alpha2Code": "YE",
#         "alpha3Code": "YEM",
#         "altSpellings": [
#             "YE",
#             "Yemeni Republic",
#             "al-Jumh\u016briyyah al-Yamaniyyah"
#         ],
#         "area": 527968.0,
#         "borders": [
#             "OMN",
#             "SAU"
#         ],
#         "callingCodes": [
#             "967"
#         ],
#         "capital": "Sana'a",
#         "cioc": "YEM",
#         "currencies": [
#             {
#                 "code": "YER",
#                 "name": "Yemeni rial",
#                 "symbol": "\ufdfc"
#             }
#         ],
#         "demonym": "Yemeni",
#         "flag": "https://restcountries.eu/data/yem.svg",
#         "gini": 37.7,
#         "languages": [
#             {
#                 "iso639_1": "ar",
#                 "iso639_2": "ara",
#                 "name": "Arabic",
#                 "nativeName": "\u0627\u0644\u0639\u0631\u0628\u064a\u0629"
#             }
#         ],
#         "latlng": [
#             15.0,
#             48.0
#         ],
#         "name": "Yemen",
#         "nativeName": "\u0627\u0644\u064a\u064e\u0645\u064e\u0646",
#         "numericCode": "887",
#         "population": 27478000,
#         "region": "Asia",
#         "regionalBlocs": [
#             {
#                 "acronym": "AL",
#                 "name": "Arab League",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u062c\u0627\u0645\u0639\u0629 \u0627\u0644\u062f\u0648\u0644 \u0627\u0644\u0639\u0631\u0628\u064a\u0629",
#                     "J\u0101mi\u02bbat ad-Duwal al-\u02bbArab\u012byah",
#                     "League of Arab States"
#                 ]
#             }
#         ],
#         "subregion": "Western Asia",
#         "timezones": [
#             "UTC+03:00"
#         ],
#         "topLevelDomain": [
#             ".ye"
#         ],
#         "translations": {
#             "br": "I\u00eamen",
#             "de": "Jemen",
#             "es": "Yemen",
#             "fa": "\u06cc\u0645\u0646",
#             "fr": "Y\u00e9men",
#             "hr": "Jemen",
#             "it": "Yemen",
#             "ja": "\u30a4\u30a8\u30e1\u30f3",
#             "nl": "Jemen",
#             "pt": "I\u00e9men"
#         }
#     },
#     {
#         "alpha2Code": "ZM",
#         "alpha3Code": "ZMB",
#         "altSpellings": [
#             "ZM",
#             "Republic of Zambia"
#         ],
#         "area": 752612.0,
#         "borders": [
#             "AGO",
#             "BWA",
#             "COD",
#             "MWI",
#             "MOZ",
#             "NAM",
#             "TZA",
#             "ZWE"
#         ],
#         "callingCodes": [
#             "260"
#         ],
#         "capital": "Lusaka",
#         "cioc": "ZAM",
#         "currencies": [
#             {
#                 "code": "ZMW",
#                 "name": "Zambian kwacha",
#                 "symbol": "ZK"
#             }
#         ],
#         "demonym": "Zambian",
#         "flag": "https://restcountries.eu/data/zmb.svg",
#         "gini": 54.6,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             }
#         ],
#         "latlng": [
#             -15.0,
#             30.0
#         ],
#         "name": "Zambia",
#         "nativeName": "Zambia",
#         "numericCode": "894",
#         "population": 15933883,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Eastern Africa",
#         "timezones": [
#             "UTC+02:00"
#         ],
#         "topLevelDomain": [
#             ".zm"
#         ],
#         "translations": {
#             "br": "Z\u00e2mbia",
#             "de": "Sambia",
#             "es": "Zambia",
#             "fa": "\u0632\u0627\u0645\u0628\u06cc\u0627",
#             "fr": "Zambie",
#             "hr": "Zambija",
#             "it": "Zambia",
#             "ja": "\u30b6\u30f3\u30d3\u30a2",
#             "nl": "Zambia",
#             "pt": "Z\u00e2mbia"
#         }
#     },
#     {
#         "alpha2Code": "ZW",
#         "alpha3Code": "ZWE",
#         "altSpellings": [
#             "ZW",
#             "Republic of Zimbabwe"
#         ],
#         "area": 390757.0,
#         "borders": [
#             "BWA",
#             "MOZ",
#             "ZAF",
#             "ZMB"
#         ],
#         "callingCodes": [
#             "263"
#         ],
#         "capital": "Harare",
#         "cioc": "ZIM",
#         "currencies": [
#             {
#                 "code": "BWP",
#                 "name": "Botswana pula",
#                 "symbol": "P"
#             },
#             {
#                 "code": "GBP",
#                 "name": "British pound",
#                 "symbol": "\u00a3"
#             },
#             {
#                 "code": "CNY",
#                 "name": "Chinese yuan",
#                 "symbol": "\u00a5"
#             },
#             {
#                 "code": "EUR",
#                 "name": "Euro",
#                 "symbol": "\u20ac"
#             },
#             {
#                 "code": "INR",
#                 "name": "Indian rupee",
#                 "symbol": "\u20b9"
#             },
#             {
#                 "code": "JPY",
#                 "name": "Japanese yen",
#                 "symbol": "\u00a5"
#             },
#             {
#                 "code": "ZAR",
#                 "name": "South African rand",
#                 "symbol": "Rs"
#             },
#             {
#                 "code": "USD",
#                 "name": "United States dollar",
#                 "symbol": "$"
#             },
#             {
#                 "code": "(none)",
#                 "name": null,
#                 "symbol": null
#             }
#         ],
#         "demonym": "Zimbabwean",
#         "flag": "https://restcountries.eu/data/zwe.svg",
#         "gini": null,
#         "languages": [
#             {
#                 "iso639_1": "en",
#                 "iso639_2": "eng",
#                 "name": "English",
#                 "nativeName": "English"
#             },
#             {
#                 "iso639_1": "sn",
#                 "iso639_2": "sna",
#                 "name": "Shona",
#                 "nativeName": "chiShona"
#             },
#             {
#                 "iso639_1": "nd",
#                 "iso639_2": "nde",
#                 "name": "Northern Ndebele",
#                 "nativeName": "isiNdebele"
#             }
#         ],
#         "latlng": [
#             -20.0,
#             30.0
#         ],
#         "name": "Zimbabwe",
#         "nativeName": "Zimbabwe",
#         "numericCode": "716",
#         "population": 14240168,
#         "region": "Africa",
#         "regionalBlocs": [
#             {
#                 "acronym": "AU",
#                 "name": "African Union",
#                 "otherAcronyms": [],
#                 "otherNames": [
#                     "\u0627\u0644\u0627\u062a\u062d\u0627\u062f \u0627\u0644\u0623\u0641\u0631\u064a\u0642\u064a",
#                     "Union africaine",
#                     "Uni\u00e3o Africana",
#                     "Uni\u00f3n Africana",
#                     "Umoja wa Afrika"
#                 ]
#             }
#         ],
#         "subregion": "Eastern Africa",
#         "timezones": [
#             "UTC+02:00"
#         ],
#         "topLevelDomain": [
#             ".zw"
#         ],
#         "translations": {
#             "br": "Zimbabwe",
#             "de": "Simbabwe",
#             "es": "Zimbabue",
#             "fa": "\u0632\u06cc\u0645\u0628\u0627\u0648\u0647",
#             "fr": "Zimbabwe",
#             "hr": "Zimbabve",
#             "it": "Zimbabwe",
#             "ja": "\u30b8\u30f3\u30d0\u30d6\u30a8",
#             "nl": "Zimbabwe",
#             "pt": "Zimbabu\u00e9"
#         }
#     }
# ]

# %%
# Determine how many countries are included in this data set
nCountriesCodes = len(country_data)

# Initialize lists
nameCountry = []       # name of country
a2cCountry = []        # ISO 3166-1 2-letter country code
a3cCountry = []        # ISO 3166-1 3-letter country code
latlng = []            # geocache data

# Start gathering data for all countries. 
# If a country's data can not be obtained then skip entry and move on to the next...

for code in np.arange(0,nCountriesCodes,1):
    
    try:
        nameCountry.append(country_data[code]["name"])
        a3cCountry.append(country_data[code]["alpha3Code"])
        a2cCountry.append(country_data[code]["alpha2Code"])
        latlng.append(country_data[code]["latlng"])

    except:
        print(f"Country Not Listed in index {code}... skipping.")

# %%
# Construct dataframe with country, code, and geocoordinates
raw_codes_df = pd.DataFrame({"Country":nameCountry,
                                "Code":a3cCountry,
                                ##"2Code":a2cCountry,
                                "Location":latlng})
raw_codes_df.head(3)
# Out:
#          Country Code           Location
# 0    Afghanistan  AFG       [33.0, 65.0]
# 1  Åland Islands  ALA  [60.116667, 19.9]
# 2        Albania  ALB       [41.0, 20.0]

# %%
# Add ISO country codes and location of country to master_df
geoMaster = master_df.merge(raw_codes_df,left_on= "country",right_on="Country",how="left")
geoMaster
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 0                   6.71     Albania1987           NaN      2,156,624,900
# 1                   5.19     Albania1987           NaN      2,156,624,900
# 2                   4.83     Albania1987           NaN      2,156,624,900
# 3                   4.59     Albania1987           NaN      2,156,624,900
# 4                   3.28     Albania1987           NaN      2,156,624,900
# ...                  ...             ...           ...                ...
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)       generation     Country Code      Location
# 0                     796     Generation X     Albania  ALB  [41.0, 20.0]
# 1                     796           Silent     Albania  ALB  [41.0, 20.0]
# 2                     796     Generation X     Albania  ALB  [41.0, 20.0]
# 3                     796  G.I. Generation     Albania  ALB  [41.0, 20.0]
# 4                     796          Boomers     Albania  ALB  [41.0, 20.0]
# ...                   ...              ...         ...  ...           ...
# 27815                2309     Generation X  Uzbekistan  UZB  [41.0, 64.0]
# 27816                2309           Silent  Uzbekistan  UZB  [41.0, 64.0]
# 27817                2309     Generation Z  Uzbekistan  UZB  [41.0, 64.0]
# 27818                2309     Generation Z  Uzbekistan  UZB  [41.0, 64.0]
# 27819                2309          Boomers  Uzbekistan  UZB  [41.0, 64.0]
#
# [27820 rows x 15 columns]

# %%
# The following countries were not merged correctly (i.e., country names differ in spelling)
unfoundCountries = geoMaster.loc[pd.isnull(geoMaster["Code"])]
print(f"List of unmatched coutries:\n{unfoundCountries['country'].unique()}")
# Out:
# List of unmatched coutries:
# ['Macau' 'Republic of Korea' 'Saint Vincent and Grenadines'
#  'United Kingdom' 'United States']

# %%
# Print list of troublesome countries (countries with no name matches)
print(raw_codes_df[raw_codes_df['Country'].str.contains("States")]["Country"])
# Out:
# 33     United States Minor Outlying Islands
# 145        Micronesia (Federated States of)
# 239                United States of America
# Name: Country, dtype: object

# %%
# Correct master data to facilitate finding ISO-codes
corrections = {"Macau":"Macao",
              "Republic of Korea":"Korea (Republic of)",
              "Saint Vincent and Grenadines":"Saint Vincent and the Grenadines",
              "United Kingdom":"United Kingdom of Great Britain and Northern Ireland",
              "United States":"United States of America"}

# Make name corrections master data set
for country in corrections:
    oldName = country
    newName = corrections[country]
    master_df.loc[master_df["country"] == oldName,"country"] = newName

# %%
# Make the merge again (after correction)
geoMaster = master_df.merge(raw_codes_df,left_on= "country",right_on="Country",how="left")
geoMaster
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 0                   6.71     Albania1987           NaN      2,156,624,900
# 1                   5.19     Albania1987           NaN      2,156,624,900
# 2                   4.83     Albania1987           NaN      2,156,624,900
# 3                   4.59     Albania1987           NaN      2,156,624,900
# 4                   3.28     Albania1987           NaN      2,156,624,900
# ...                  ...             ...           ...                ...
# 27815               2.96  Uzbekistan2014         0.675     63,067,077,179
# 27816               2.58  Uzbekistan2014         0.675     63,067,077,179
# 27817               2.17  Uzbekistan2014         0.675     63,067,077,179
# 27818               1.67  Uzbekistan2014         0.675     63,067,077,179
# 27819               1.46  Uzbekistan2014         0.675     63,067,077,179
#
#        gdp_per_capita ($)       generation     Country Code      Location
# 0                     796     Generation X     Albania  ALB  [41.0, 20.0]
# 1                     796           Silent     Albania  ALB  [41.0, 20.0]
# 2                     796     Generation X     Albania  ALB  [41.0, 20.0]
# 3                     796  G.I. Generation     Albania  ALB  [41.0, 20.0]
# 4                     796          Boomers     Albania  ALB  [41.0, 20.0]
# ...                   ...              ...         ...  ...           ...
# 27815                2309     Generation X  Uzbekistan  UZB  [41.0, 64.0]
# 27816                2309           Silent  Uzbekistan  UZB  [41.0, 64.0]
# 27817                2309     Generation Z  Uzbekistan  UZB  [41.0, 64.0]
# 27818                2309     Generation Z  Uzbekistan  UZB  [41.0, 64.0]
# 27819                2309          Boomers  Uzbekistan  UZB  [41.0, 64.0]
#
# [27820 rows x 15 columns]

# %% [markdown]
# ### Start of Data Extraction

# %%
# Ensure we have a complete match!
unfoundCountries = geoMaster.loc[pd.isnull(geoMaster["Code"])]
print(f"List of unmatched coutries:\n{unfoundCountries['country'].unique()}")
# Out:
# List of unmatched coutries:
# []

# %%
# List number of different countries
noCountries = len(geoMaster["country"].unique())
noCountries
# Out:
# 101

# %%
# List of different countries
nameCountries = geoMaster["country"].unique()
nameCountries
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macao', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Korea (Republic of)', 'Romania', 'Russian Federation',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino', 'Serbia',
#        'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Suriname', 'Sweden', 'Switzerland',
#        'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turkmenistan',
#        'Ukraine', 'United Arab Emirates',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States of America', 'Uruguay', 'Uzbekistan'], dtype=object)

# %%
# Determine suicide totals per year per country
total_suicides = geoMaster.groupby(["Country","Code","year"]).sum()[["suicides_no","population"]]
total_suicides.head()
# Out:
#                    suicides_no  population
# Country Code year
# Albania ALB  1987           73     2709600
#              1988           63     2764300
#              1989           68     2803100
#              1992           47     2822500
#              1993           73     2807300

# %%
# Determine suicide rate (per 100k) for the entire year
tot = [];
for i in np.arange(0,len(total_suicides["suicides_no"])):
    tot.append(round(total_suicides["suicides_no"][i]/total_suicides["population"][i]*100000,2))

# %%
# Add total suicide rate to dataframe
total_suicides["total suicides/100k pop"] = tot

# %%
# Display total suicides dataframe
total_suicides.head()
# Out:
#                    suicides_no  population  total suicides/100k pop
# Country Code year
# Albania ALB  1987           73     2709600                     2.69
#              1988           63     2764300                     2.28
#              1989           68     2803100                     2.43
#              1992           47     2822500                     1.67
#              1993           73     2807300                     2.60

# %%
# Let's collapse the mulitindices
flip = total_suicides.reset_index()
flip.head(30)
flip_output = os.path.join(".","Data/suicide_data.csv")
flip.to_csv(flip_output, index_label="index")

# %%
# Retrive the latest year when suicide data was recorded
countryLastDate = flip[["Country","Code","year"]].groupby(["Country","Code"]).max()
countryLastDate= countryLastDate.reset_index()
countryLastDate
# Out:
#                                                Country Code  year
# 0                                              Albania  ALB  2010
# 1                                  Antigua and Barbuda  ATG  2015
# 2                                            Argentina  ARG  2015
# 3                                              Armenia  ARM  2016
# 4                                                Aruba  ABW  2011
# ..                                                 ...  ...   ...
# 96                                United Arab Emirates  ARE  2010
# 97   United Kingdom of Great Britain and Northern I...  GBR  2015
# 98                            United States of America  USA  2015
# 99                                             Uruguay  URY  2015
# 100                                         Uzbekistan  UZB  2014
#
# [101 rows x 3 columns]

# %%
# Testing out how multiindex references work...
total_suicides.loc[('Albania', 'ALB', 1987)]
# Out:
# suicides_no                     73.00
# population                 2709600.00
# total suicides/100k pop          2.69
# Name: (Albania, ALB, 1987), dtype: float64

# %%
# For the last year when data was recorded (per country) pull the corresponding
# number of suicides, population, and suicide rate
latestSuicideNo = []
latestPop = []
latestSuicideRate = []
for i in countryLastDate.index:
    country = countryLastDate.loc[i]['Country']
    code = countryLastDate.loc[i]['Code']
    latest_year = countryLastDate.loc[i]['year']
    entry = total_suicides.loc[(country, code, latest_year)]
    latestSuicideNo.append(entry['suicides_no'])
    latestPop.append(entry['population'])
    latestSuicideRate.append(entry['total suicides/100k pop'])

# %%
# Add latest data LastDate dataframe
countryLastDate["suicides_no"] = latestSuicideNo
countryLastDate["population"] = latestPop
countryLastDate["total suicides/100k pop"] = latestSuicideRate
countryLastDate
# Out:
#                                                Country Code  year  \
# 0                                              Albania  ALB  2010
# 1                                  Antigua and Barbuda  ATG  2015
# 2                                            Argentina  ARG  2015
# 3                                              Armenia  ARM  2016
# 4                                                Aruba  ABW  2011
# ..                                                 ...  ...   ...
# 96                                United Arab Emirates  ARE  2010
# 97   United Kingdom of Great Britain and Northern I...  GBR  2015
# 98                            United States of America  USA  2015
# 99                                             Uruguay  URY  2015
# 100                                         Uzbekistan  UZB  2014
#
#      suicides_no   population  total suicides/100k pop
# 0           96.0    2736025.0                     3.51
# 1            1.0      91889.0                     1.09
# 2         3073.0   39699624.0                     7.74
# 3           67.0    2400033.0                     2.79
# 4            9.0      95488.0                     9.43
# ..           ...          ...                      ...
# 96         111.0    7839736.0                     1.42
# 97        4910.0   61082942.0                     8.04
# 98       44189.0  300078511.0                    14.73
# 99         630.0    3190795.0                    19.74
# 100       2095.0   27313507.0                     7.67
#
# [101 rows x 6 columns]

# %%
# no of countries with data available for years 2015 and 2016
#idx = pd.IndexSlice
#len(total_suicides.loc[idx[:,:, [2015,2016]], :].index.unique(level='Country'))

# %%
# Pull suicide rates for 2015 and 2016 only
#suicideRate2015 = total_suicides.loc[idx[:,:, [2015]], :]["total suicides/100k pop"].to_frame().reset_index()
#suicideRate2015 = suicideRate2015.drop(columns=["Country","year"])

# %%
##total_suicides.loc[(slice(None), slice(None), [2015,2016]), :]
## this code also works, just commented out but wanted to keep as notes

# %%
# Create suicide pivot table
suicidePivot = pd.pivot_table(geoMaster, 
                             values=["suicides/100k pop"], 
                             index=["Country","Code","year"],
                             columns=["age", "sex"])

# %%
# Display the pivot table
suicidePivot
# Out:
#                      suicides/100k pop                                        \
# age                        15-24 years        25-34 years        35-54 years
# sex                             female   male      female   male      female
# Country    Code year
# Albania    ALB  1987              4.83   6.71        1.56   3.28        2.15
#                 1988              2.71   5.33        1.91   1.79        1.41
#                 1989              1.67   3.71        0.75   6.35        2.43
#                 1992              2.39   3.41        1.50   2.85        0.62
#                 1993              3.51   7.40        2.67   3.91        2.11
# ...                                ...    ...         ...    ...         ...
# Uzbekistan UZB  2010              6.71   7.67        3.89   9.89        3.02
#                 2011              8.02   8.22        5.63  11.03        2.29
#                 2012             10.84   9.72        5.79  11.38        2.56
#                 2013             10.63  10.09        5.51  12.40        2.79
#                 2014             11.59  11.10        5.92  11.61        2.96
#
#                                                                            \
# age                         5-14 years       55-74 years        75+ years
# sex                    male     female  male      female   male    female
# Country    Code year
# Albania    ALB  1987   5.19       0.00  0.00        0.00   0.73      2.81
#                 1988   4.46       0.00  0.00        2.03   2.85      5.49
#                 1989   4.71       0.00  0.00        0.67   4.22      0.00
#                 1992   3.49       0.00  0.00        0.61   3.13      0.00
#                 1993   2.85       0.29  0.27        1.18   4.24      0.00
# ...                     ...        ...   ...         ...    ...       ...
# Uzbekistan UZB  2010  11.81       1.14  1.74        1.38   9.84      1.55
#                 2011  14.26       1.08  1.66        1.56   7.00      1.51
#                 2012  12.34       0.62  2.48        1.95  11.65      1.18
#                 2013  14.37       1.19  2.24        1.55   9.89      2.32
#                 2014  15.17       1.67  2.17        1.46  11.33      2.58
#
#
# age
# sex                   male
# Country    Code year
# Albania    ALB  1987  4.59
#                 1988  4.48
#                 1989  8.89
#                 1992  0.00
#                 1993  4.13
# ...                    ...
# Uzbekistan UZB  2010  4.59
#                 2011  4.88
#                 2012  7.02
#                 2013  5.88
#                 2014  7.56
#
# [2321 rows x 12 columns]

# %%
# Add a column
suicidePivot[('suicides/100k pop',"All Ages","both")]=total_suicides["total suicides/100k pop"]

# %%
# Display the pivot table
suicidePivot.head()
# Out:
#                   suicides/100k pop                                            \
# age                     15-24 years       25-34 years       35-54 years
# sex                          female  male      female  male      female  male
# Country Code year
# Albania ALB  1987              4.83  6.71        1.56  3.28        2.15  5.19
#              1988              2.71  5.33        1.91  1.79        1.41  4.46
#              1989              1.67  3.71        0.75  6.35        2.43  4.71
#              1992              2.39  3.41        1.50  2.85        0.62  3.49
#              1993              3.51  7.40        2.67  3.91        2.11  2.85
#
#
# age               5-14 years       55-74 years       75+ years       All Ages
# sex                   female  male      female  male    female  male     both
# Country Code year
# Albania ALB  1987       0.00  0.00        0.00  0.73      2.81  4.59     2.69
#              1988       0.00  0.00        2.03  2.85      5.49  4.48     2.28
#              1989       0.00  0.00        0.67  4.22      0.00  8.89     2.43
#              1992       0.00  0.00        0.61  3.13      0.00  0.00     1.67
#              1993       0.29  0.27        1.18  4.24      0.00  4.13     2.60

# %% [markdown]
# ### Convert Suicide Table to a JSON

# %%
# Initialize JSON
sJSON = [];

# Create a list of different age groups (all is not an age group)
ageGrps = list(suicidePivot.columns.levels[1])

# Construct a dictionary with the following fields:
# country, code, year, male (rates), female (rates), both (rate)
for i in suicidePivot.index:
    iJSON = {}
    iJSON["country"] = i[0]
    iJSON["code"]= i[1]
    iJSON["year"]=i[2]
    mData = {}
    fData = {}
    bData = {}
    for g in ageGrps[0:len(ageGrps)-1]:
        if pd.notna(suicidePivot.loc[(i[0],i[1],i[2])][("suicides/100k pop",g,"male")]):
            mData[g] = suicidePivot.loc[(i[0],i[1],i[2])][("suicides/100k pop",g,"male")]
        if pd.notna(suicidePivot.loc[(i[0],i[1],i[2])][("suicides/100k pop",g,"female")]):
            fData[g] = suicidePivot.loc[(i[0],i[1],i[2])][("suicides/100k pop",g,"female")]
    iJSON["male"] = mData
    iJSON["female"] = fData
    bData["all ages"] = suicidePivot.loc[(i[0],i[1],i[2])][("suicides/100k pop","All Ages","both")]
    iJSON["both"] = bData
    sJSON.append(iJSON)

# %%
#Display JSON
sJSON
# Out:
# [{'country': 'Albania',
#   'code': 'ALB',
#   'year': 1987,
#   'male': {'15-24 years': 6.71,
#    '25-34 years': 3.28,
#    '35-54 years': 5.19,
#    '5-14 years': 0.0,
#    '55-74 years': 0.73,
#    '75+ years': 4.59},
#   'female': {'15-24 years': 4.83,
#    '25-34 years': 1.56,
#    '35-54 years': 2.15,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 2.81},
#   'both': {'all ages': 2.69}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1988,
#   'male': {'15-24 years': 5.33,
#    '25-34 years': 1.79,
#    '35-54 years': 4.46,
#    '5-14 years': 0.0,
#    '55-74 years': 2.85,
#    '75+ years': 4.48},
#   'female': {'15-24 years': 2.71,
#    '25-34 years': 1.91,
#    '35-54 years': 1.41,
#    '5-14 years': 0.0,
#    '55-74 years': 2.03,
#    '75+ years': 5.49},
#   'both': {'all ages': 2.28}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1989,
#   'male': {'15-24 years': 3.71,
#    '25-34 years': 6.35,
#    '35-54 years': 4.71,
#    '5-14 years': 0.0,
#    '55-74 years': 4.22,
#    '75+ years': 8.89},
#   'female': {'15-24 years': 1.67,
#    '25-34 years': 0.75,
#    '35-54 years': 2.43,
#    '5-14 years': 0.0,
#    '55-74 years': 0.67,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.43}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1992,
#   'male': {'15-24 years': 3.41,
#    '25-34 years': 2.85,
#    '35-54 years': 3.49,
#    '5-14 years': 0.0,
#    '55-74 years': 3.13,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 2.39,
#    '25-34 years': 1.5,
#    '35-54 years': 0.62,
#    '5-14 years': 0.0,
#    '55-74 years': 0.61,
#    '75+ years': 0.0},
#   'both': {'all ages': 1.67}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1993,
#   'male': {'15-24 years': 7.4,
#    '25-34 years': 3.91,
#    '35-54 years': 2.85,
#    '5-14 years': 0.27,
#    '55-74 years': 4.24,
#    '75+ years': 4.13},
#   'female': {'15-24 years': 3.51,
#    '25-34 years': 2.67,
#    '35-54 years': 2.11,
#    '5-14 years': 0.29,
#    '55-74 years': 1.18,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.6}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1994,
#   'male': {'15-24 years': 2.48,
#    '25-34 years': 2.59,
#    '35-54 years': 2.48,
#    '5-14 years': 0.27,
#    '55-74 years': 6.42,
#    '75+ years': 8.13},
#   'female': {'15-24 years': 2.12,
#    '25-34 years': 1.53,
#    '35-54 years': 0.58,
#    '5-14 years': 0.0,
#    '55-74 years': 0.57,
#    '75+ years': 5.01},
#   'both': {'all ages': 1.75}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1995,
#   'male': {'15-24 years': 4.56,
#    '25-34 years': 5.58,
#    '35-54 years': 3.72,
#    '5-14 years': 1.59,
#    '55-74 years': 5.06,
#    '75+ years': 3.98},
#   'female': {'15-24 years': 4.59,
#    '25-34 years': 2.65,
#    '35-54 years': 2.24,
#    '5-14 years': 0.57,
#    '55-74 years': 1.11,
#    '75+ years': 4.9},
#   'both': {'all ages': 3.03}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1996,
#   'male': {'15-24 years': 6.98,
#    '25-34 years': 5.95,
#    '35-54 years': 3.16,
#    '5-14 years': 0.53,
#    '55-74 years': 1.67,
#    '75+ years': 7.87},
#   'female': {'15-24 years': 5.56,
#    '25-34 years': 3.73,
#    '35-54 years': 2.49,
#    '5-14 years': 0.28,
#    '55-74 years': 0.55,
#    '75+ years': 4.85},
#   'both': {'all ages': 3.03}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1997,
#   'male': {'15-24 years': 13.5,
#    '25-34 years': 15.25,
#    '35-54 years': 7.88,
#    '5-14 years': 1.05,
#    '55-74 years': 6.66,
#    '75+ years': 11.81},
#   'female': {'15-24 years': 7.14,
#    '25-34 years': 5.84,
#    '35-54 years': 1.89,
#    '5-14 years': 1.66,
#    '55-74 years': 0.0,
#    '75+ years': 4.75},
#   'both': {'all ages': 5.71}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1998,
#   'male': {'15-24 years': 10.85,
#    '25-34 years': 10.82,
#    '35-54 years': 7.47,
#    '5-14 years': 0.51,
#    '55-74 years': 4.9,
#    '75+ years': 11.63},
#   'female': {'15-24 years': 10.83,
#    '25-34 years': 3.63,
#    '35-54 years': 2.42,
#    '5-14 years': 0.27,
#    '55-74 years': 3.19,
#    '75+ years': 0.0},
#   'both': {'all ages': 5.11}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 1999,
#   'male': {'15-24 years': 9.58,
#    '25-34 years': 7.84,
#    '35-54 years': 7.93,
#    '5-14 years': 0.0,
#    '55-74 years': 7.56,
#    '75+ years': 11.58},
#   'female': {'15-24 years': 6.4,
#    '25-34 years': 4.7,
#    '35-54 years': 1.34,
#    '5-14 years': 0.27,
#    '55-74 years': 3.18,
#    '75+ years': 9.43},
#   'both': {'all ages': 4.59}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2000,
#   'male': {'15-24 years': 2.08,
#    '25-34 years': 7.33,
#    '35-54 years': 1.07,
#    '5-14 years': 0.27,
#    '55-74 years': 5.64,
#    '75+ years': 4.02},
#   'female': {'15-24 years': 2.27,
#    '25-34 years': 1.22,
#    '35-54 years': 1.51,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 5.29},
#   'both': {'all ages': 1.93}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2001,
#   'male': {'15-24 years': 3.91,
#    '25-34 years': 10.65,
#    '35-54 years': 8.98,
#    '5-14 years': 1.87,
#    '55-74 years': 5.59,
#    '75+ years': 3.22},
#   'female': {'15-24 years': 3.32,
#    '25-34 years': 1.8,
#    '35-54 years': 3.24,
#    '5-14 years': 0.65,
#    '55-74 years': 3.16,
#    '75+ years': 4.23},
#   'both': {'all ages': 4.25}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2002,
#   'male': {'15-24 years': 5.7,
#    '25-34 years': 11.15,
#    '35-54 years': 9.16,
#    '5-14 years': 0.31,
#    '55-74 years': 6.56,
#    '75+ years': 12.9},
#   'female': {'15-24 years': 5.07,
#    '25-34 years': 3.13,
#    '35-54 years': 4.0,
#    '5-14 years': 0.33,
#    '55-74 years': 2.09,
#    '75+ years': 2.11},
#   'both': {'all ages': 4.72}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2003,
#   'male': {'15-24 years': 5.49,
#    '25-34 years': 4.38,
#    '35-54 years': 7.25,
#    '5-14 years': 1.28,
#    '55-74 years': 7.94,
#    '75+ years': 3.06},
#   'female': {'15-24 years': 4.93,
#    '25-34 years': 4.04,
#    '35-54 years': 3.41,
#    '5-14 years': 0.0,
#    '55-74 years': 4.6,
#    '75+ years': 12.22},
#   'both': {'all ages': 4.36}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2004,
#   'male': {'15-24 years': 6.63,
#    '25-34 years': 7.85,
#    '35-54 years': 9.95,
#    '5-14 years': 0.33,
#    '55-74 years': 4.83,
#    '75+ years': 11.26},
#   'female': {'15-24 years': 6.84,
#    '25-34 years': 4.95,
#    '35-54 years': 4.34,
#    '5-14 years': 1.05,
#    '55-74 years': 1.47,
#    '75+ years': 5.89},
#   'both': {'all ages': 5.08}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2005,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2006,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2007,
#   'male': {'15-24 years': 4.51,
#    '25-34 years': 5.22,
#    '35-54 years': 7.66,
#    '5-14 years': 1.47,
#    '55-74 years': 6.25,
#    '75+ years': 18.88},
#   'female': {'15-24 years': 4.63,
#    '25-34 years': 4.36,
#    '35-54 years': 3.57,
#    '5-14 years': 0.0,
#    '55-74 years': 4.07,
#    '75+ years': 5.23},
#   'both': {'all ages': 4.48}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2008,
#   'male': {'15-24 years': 3.84,
#    '25-34 years': 12.15,
#    '35-54 years': 9.81,
#    '5-14 years': 2.67,
#    '55-74 years': 9.18,
#    '75+ years': 4.49},
#   'female': {'15-24 years': 7.24,
#    '25-34 years': 4.93,
#    '35-54 years': 4.82,
#    '5-14 years': 0.41,
#    '55-74 years': 3.09,
#    '75+ years': 8.42},
#   'both': {'all ages': 5.8}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2009,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Albania',
#   'code': 'ALB',
#   'year': 2010,
#   'male': {'15-24 years': 3.58,
#    '25-34 years': 5.01,
#    '35-54 years': 5.38,
#    '5-14 years': 0.0,
#    '55-74 years': 8.27,
#    '75+ years': 3.94},
#   'female': {'15-24 years': 2.28,
#    '25-34 years': 3.27,
#    '35-54 years': 3.04,
#    '5-14 years': 0.89,
#    '55-74 years': 2.9,
#    '75+ years': 3.1},
#   'both': {'all ages': 3.51}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1985,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1986,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1987,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1988,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1989,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1990,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 17.24,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 1.69}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1991,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1992,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1993,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 15.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 1.58}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1994,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1995,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1998,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 1999,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2000,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 9.97,
#    '5-14 years': 0.0,
#    '55-74 years': 30.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.66}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2001,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 19.45,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.61}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2002,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2003,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 27.82,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 1.27}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2004,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 8.77,
#    '5-14 years': 0.0,
#    '55-74 years': 27.29,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.51}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2005,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2006,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2007,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 7.98,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 1.2}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2008,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2009,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2012,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2013,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2014,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 0.0}},
#  {'country': 'Antigua and Barbuda',
#   'code': 'ATG',
#   'year': 2015,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 15.62,
#    '75+ years': 0.0},
#   'both': {'all ages': 1.09}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1985,
#   'male': {'15-24 years': 6.46,
#    '25-34 years': 7.92,
#    '35-54 years': 12.37,
#    '5-14 years': 0.53,
#    '55-74 years': 24.29,
#    '75+ years': 55.65},
#   'female': {'15-24 years': 2.93,
#    '25-34 years': 2.97,
#    '35-54 years': 4.23,
#    '5-14 years': 0.37,
#    '55-74 years': 9.11,
#    '75+ years': 7.64},
#   'both': {'all ages': 7.34}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1986,
#   'male': {'15-24 years': 7.66,
#    '25-34 years': 9.3,
#    '35-54 years': 14.2,
#    '5-14 years': 0.33,
#    '55-74 years': 26.39,
#    '75+ years': 63.01},
#   'female': {'15-24 years': 4.27,
#    '25-34 years': 4.37,
#    '35-54 years': 5.57,
#    '5-14 years': 0.24,
#    '55-74 years': 8.67,
#    '75+ years': 8.89},
#   'both': {'all ages': 8.38}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1987,
#   'male': {'15-24 years': 7.27,
#    '25-34 years': 8.44,
#    '35-54 years': 14.14,
#    '5-14 years': 0.48,
#    '55-74 years': 26.15,
#    '75+ years': 54.08},
#   'female': {'15-24 years': 3.88,
#    '25-34 years': 4.0,
#    '35-54 years': 6.11,
#    '5-14 years': 0.47,
#    '55-74 years': 9.54,
#    '75+ years': 10.42},
#   'both': {'all ages': 8.28}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1988,
#   'male': {'15-24 years': 8.36,
#    '25-34 years': 9.45,
#    '35-54 years': 13.62,
#    '5-14 years': 0.62,
#    '55-74 years': 26.46,
#    '75+ years': 55.1},
#   'female': {'15-24 years': 4.11,
#    '25-34 years': 2.74,
#    '35-54 years': 5.64,
#    '5-14 years': 0.35,
#    '55-74 years': 9.66,
#    '75+ years': 10.13},
#   'both': {'all ages': 8.32}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1989,
#   'male': {'15-24 years': 7.22,
#    '25-34 years': 9.58,
#    '35-54 years': 12.97,
#    '5-14 years': 0.55,
#    '55-74 years': 26.03,
#    '75+ years': 52.0},
#   'female': {'15-24 years': 3.19,
#    '25-34 years': 3.71,
#    '35-54 years': 4.66,
#    '5-14 years': 0.35,
#    '55-74 years': 8.22,
#    '75+ years': 10.45},
#   'both': {'all ages': 7.83}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1990,
#   'male': {'15-24 years': 6.6,
#    '25-34 years': 7.92,
#    '35-54 years': 12.13,
#    '5-14 years': 0.67,
#    '55-74 years': 23.59,
#    '75+ years': 54.97},
#   'female': {'15-24 years': 3.54,
#    '25-34 years': 3.38,
#    '35-54 years': 4.5,
#    '5-14 years': 0.44,
#    '55-74 years': 7.67,
#    '75+ years': 9.49},
#   'both': {'all ages': 7.36}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1991,
#   'male': {'15-24 years': 6.54,
#    '25-34 years': 9.4,
#    '35-54 years': 11.12,
#    '5-14 years': 0.83,
#    '55-74 years': 21.08,
#    '75+ years': 46.46},
#   'female': {'15-24 years': 2.27,
#    '25-34 years': 3.33,
#    '35-54 years': 3.6,
#    '5-14 years': 0.27,
#    '55-74 years': 6.74,
#    '75+ years': 7.6},
#   'both': {'all ages': 6.59}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1992,
#   'male': {'15-24 years': 8.79,
#    '25-34 years': 9.84,
#    '35-54 years': 13.49,
#    '5-14 years': 0.65,
#    '55-74 years': 23.25,
#    '75+ years': 47.91},
#   'female': {'15-24 years': 2.84,
#    '25-34 years': 3.39,
#    '35-54 years': 3.73,
#    '5-14 years': 0.4,
#    '55-74 years': 5.79,
#    '75+ years': 6.78},
#   'both': {'all ages': 7.27}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1993,
#   'male': {'15-24 years': 8.01,
#    '25-34 years': 9.97,
#    '35-54 years': 13.48,
#    '5-14 years': 0.74,
#    '55-74 years': 23.95,
#    '75+ years': 55.37},
#   'female': {'15-24 years': 2.54,
#    '25-34 years': 3.24,
#    '35-54 years': 3.77,
#    '5-14 years': 0.49,
#    '55-74 years': 4.91,
#    '75+ years': 8.3},
#   'both': {'all ages': 7.32}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1994,
#   'male': {'15-24 years': 8.26,
#    '25-34 years': 9.54,
#    '35-54 years': 14.13,
#    '5-14 years': 0.8,
#    '55-74 years': 23.22,
#    '75+ years': 45.38},
#   'female': {'15-24 years': 3.3,
#    '25-34 years': 3.04,
#    '35-54 years': 4.12,
#    '5-14 years': 0.34,
#    '55-74 years': 5.2,
#    '75+ years': 4.72},
#   'both': {'all ages': 7.25}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1995,
#   'male': {'15-24 years': 8.9,
#    '25-34 years': 9.06,
#    '35-54 years': 12.8,
#    '5-14 years': 0.45,
#    '55-74 years': 23.26,
#    '75+ years': 43.8},
#   'female': {'15-24 years': 3.31,
#    '25-34 years': 2.59,
#    '35-54 years': 3.52,
#    '5-14 years': 0.58,
#    '55-74 years': 5.1,
#    '75+ years': 6.6},
#   'both': {'all ages': 7.03}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1996,
#   'male': {'15-24 years': 8.79,
#    '25-34 years': 9.25,
#    '35-54 years': 13.62,
#    '5-14 years': 0.42,
#    '55-74 years': 20.75,
#    '75+ years': 42.4},
#   'female': {'15-24 years': 3.36,
#    '25-34 years': 2.14,
#    '35-54 years': 4.38,
#    '5-14 years': 0.28,
#    '55-74 years': 4.94,
#    '75+ years': 7.7},
#   'both': {'all ages': 7.01}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1997,
#   'male': {'15-24 years': 8.13,
#    '25-34 years': 8.66,
#    '35-54 years': 12.73,
#    '5-14 years': 0.55,
#    '55-74 years': 20.29,
#    '75+ years': 39.78},
#   'female': {'15-24 years': 3.57,
#    '25-34 years': 2.91,
#    '35-54 years': 4.04,
#    '5-14 years': 0.33,
#    '55-74 years': 4.91,
#    '75+ years': 5.5},
#   'both': {'all ages': 6.75}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1998,
#   'male': {'15-24 years': 10.08,
#    '25-34 years': 10.05,
#    '35-54 years': 12.73,
#    '5-14 years': 0.46,
#    '55-74 years': 22.77,
#    '75+ years': 39.87},
#   'female': {'15-24 years': 3.56,
#    '25-34 years': 2.07,
#    '35-54 years': 3.55,
#    '5-14 years': 0.6,
#    '55-74 years': 5.19,
#    '75+ years': 6.0},
#   'both': {'all ages': 7.16}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 1999,
#   'male': {'15-24 years': 10.82,
#    '25-34 years': 10.42,
#    '35-54 years': 13.47,
#    '5-14 years': 0.6,
#    '55-74 years': 23.46,
#    '75+ years': 39.55},
#   'female': {'15-24 years': 3.13,
#    '25-34 years': 1.95,
#    '35-54 years': 3.36,
#    '5-14 years': 0.59,
#    '55-74 years': 5.02,
#    '75+ years': 4.82},
#   'both': {'all ages': 7.3}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2000,
#   'male': {'15-24 years': 14.0,
#    '25-34 years': 12.72,
#    '35-54 years': 14.11,
#    '5-14 years': 0.51,
#    '55-74 years': 25.8,
#    '75+ years': 44.18},
#   'female': {'15-24 years': 3.57,
#    '25-34 years': 2.41,
#    '35-54 years': 4.09,
#    '5-14 years': 0.62,
#    '55-74 years': 4.82,
#    '75+ years': 4.56},
#   'both': {'all ages': 8.26}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2001,
#   'male': {'15-24 years': 15.58,
#    '25-34 years': 14.02,
#    '35-54 years': 15.08,
#    '5-14 years': 0.82,
#    '55-74 years': 27.94,
#    '75+ years': 45.66},
#   'female': {'15-24 years': 5.09,
#    '25-34 years': 3.05,
#    '35-54 years': 4.88,
#    '5-14 years': 0.7,
#    '55-74 years': 4.91,
#    '75+ years': 5.83},
#   'both': {'all ages': 9.21}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2002,
#   'male': {'15-24 years': 16.27,
#    '25-34 years': 14.94,
#    '35-54 years': 14.77,
#    '5-14 years': 1.05,
#    '55-74 years': 25.76,
#    '75+ years': 41.31},
#   'female': {'15-24 years': 4.84,
#    '25-34 years': 3.28,
#    '35-54 years': 4.45,
#    '5-14 years': 0.67,
#    '55-74 years': 6.35,
#    '75+ years': 5.73},
#   'both': {'all ages': 9.19}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2003,
#   'male': {'15-24 years': 19.15,
#    '25-34 years': 16.02,
#    '35-54 years': 14.75,
#    '5-14 years': 1.05,
#    '55-74 years': 23.83,
#    '75+ years': 46.75},
#   'female': {'15-24 years': 5.49,
#    '25-34 years': 2.41,
#    '35-54 years': 4.45,
#    '5-14 years': 0.73,
#    '55-74 years': 5.15,
#    '75+ years': 6.51},
#   'both': {'all ages': 9.45}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2004,
#   'male': {'15-24 years': 19.59,
#    '25-34 years': 15.19,
#    '35-54 years': 13.98,
#    '5-14 years': 1.22,
#    '55-74 years': 20.33,
#    '75+ years': 38.25},
#   'female': {'15-24 years': 4.88,
#    '25-34 years': 3.37,
#    '35-54 years': 4.16,
#    '5-14 years': 0.73,
#    '55-74 years': 4.7,
#    '75+ years': 4.66},
#   'both': {'all ages': 8.88}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2005,
#   'male': {'15-24 years': 19.08,
#    '25-34 years': 15.01,
#    '35-54 years': 12.43,
#    '5-14 years': 1.47,
#    '55-74 years': 19.52,
#    '75+ years': 37.43},
#   'female': {'15-24 years': 4.54,
#    '25-34 years': 3.45,
#    '35-54 years': 3.8,
#    '5-14 years': 0.62,
#    '55-74 years': 5.47,
#    '75+ years': 5.36},
#   'both': {'all ages': 8.6}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2006,
#   'male': {'15-24 years': 19.54,
#    '25-34 years': 15.74,
#    '35-54 years': 13.34,
#    '5-14 years': 1.11,
#    '55-74 years': 19.17,
#    '75+ years': 39.68},
#   'female': {'15-24 years': 5.35,
#    '25-34 years': 3.42,
#    '35-54 years': 3.52,
#    '5-14 years': 0.76,
#    '55-74 years': 3.85,
#    '75+ years': 2.74},
#   'both': {'all ages': 8.65}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2007,
#   'male': {'15-24 years': 17.07,
#    '25-34 years': 15.68,
#    '35-54 years': 12.87,
#    '5-14 years': 1.27,
#    '55-74 years': 16.96,
#    '75+ years': 35.43},
#   'female': {'15-24 years': 4.43,
#    '25-34 years': 4.04,
#    '35-54 years': 3.37,
#    '5-14 years': 1.0,
#    '55-74 years': 3.56,
#    '75+ years': 2.67},
#   'both': {'all ages': 8.11}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2008,
#   'male': {'15-24 years': 18.33,
#    '25-34 years': 16.74,
#    '35-54 years': 12.94,
#    '5-14 years': 1.1,
#    '55-74 years': 17.6,
#    '75+ years': 32.19},
#   'female': {'15-24 years': 5.42,
#    '25-34 years': 2.97,
#    '35-54 years': 3.71,
#    '5-14 years': 0.58,
#    '55-74 years': 3.5,
#    '75+ years': 3.03},
#   'both': {'all ages': 8.33}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2009,
#   'male': {'15-24 years': 17.72,
#    '25-34 years': 15.7,
#    '35-54 years': 11.87,
#    '5-14 years': 0.96,
#    '55-74 years': 16.17,
#    '75+ years': 27.09},
#   'female': {'15-24 years': 4.91,
#    '25-34 years': 3.29,
#    '35-54 years': 3.17,
#    '5-14 years': 0.82,
#    '55-74 years': 3.56,
#    '75+ years': 2.06},
#   'both': {'all ages': 7.76}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2010,
#   'male': {'15-24 years': 19.77,
#    '25-34 years': 14.98,
#    '35-54 years': 12.33,
#    '5-14 years': 0.92,
#    '55-74 years': 14.49,
#    '75+ years': 31.35},
#   'female': {'15-24 years': 4.47,
#    '25-34 years': 3.15,
#    '35-54 years': 3.37,
#    '5-14 years': 0.58,
#    '55-74 years': 3.08,
#    '75+ years': 2.75},
#   'both': {'all ages': 7.83}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2011,
#   'male': {'15-24 years': 19.96,
#    '25-34 years': 15.65,
#    '35-54 years': 10.64,
#    '5-14 years': 0.78,
#    '55-74 years': 14.92,
#    '75+ years': 26.38},
#   'female': {'15-24 years': 5.1,
#    '25-34 years': 3.16,
#    '35-54 years': 3.21,
#    '5-14 years': 0.84,
#    '55-74 years': 2.85,
#    '75+ years': 2.38},
#   'both': {'all ages': 7.66}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2012,
#   'male': {'15-24 years': 21.4,
#    '25-34 years': 18.85,
#    '35-54 years': 11.44,
#    '5-14 years': 0.8,
#    '55-74 years': 15.88,
#    '75+ years': 32.68},
#   'female': {'15-24 years': 6.03,
#    '25-34 years': 3.16,
#    '35-54 years': 3.28,
#    '5-14 years': 0.49,
#    '55-74 years': 3.24,
#    '75+ years': 2.57},
#   'both': {'all ages': 8.45}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2013,
#   'male': {'15-24 years': 19.96,
#    '25-34 years': 15.25,
#    '35-54 years': 12.2,
#    '5-14 years': 0.91,
#    '55-74 years': 13.75,
#    '75+ years': 24.03},
#   'female': {'15-24 years': 4.93,
#    '25-34 years': 3.16,
#    '35-54 years': 3.08,
#    '5-14 years': 0.91,
#    '55-74 years': 3.01,
#    '75+ years': 2.23},
#   'both': {'all ages': 7.69}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2014,
#   'male': {'15-24 years': 21.13,
#    '25-34 years': 16.2,
#    '35-54 years': 12.73,
#    '5-14 years': 0.93,
#    '55-74 years': 13.72,
#    '75+ years': 27.16},
#   'female': {'15-24 years': 6.02,
#    '25-34 years': 3.66,
#    '35-54 years': 3.77,
#    '5-14 years': 0.99,
#    '55-74 years': 3.15,
#    '75+ years': 1.89},
#   'both': {'all ages': 8.23}},
#  {'country': 'Argentina',
#   'code': 'ARG',
#   'year': 2015,
#   'male': {'15-24 years': 18.74,
#    '25-34 years': 14.13,
#    '35-54 years': 12.25,
#    '5-14 years': 1.06,
#    '55-74 years': 14.31,
#    '75+ years': 34.38},
#   'female': {'15-24 years': 4.51,
#    '25-34 years': 3.52,
#    '35-54 years': 3.13,
#    '5-14 years': 0.54,
#    '55-74 years': 3.55,
#    '75+ years': 2.01},
#   'both': {'all ages': 7.74}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1990,
#   'male': {'15-24 years': 3.67,
#    '25-34 years': 5.21,
#    '35-54 years': 7.51,
#    '5-14 years': 0.0,
#    '55-74 years': 5.98,
#    '75+ years': 7.43},
#   'female': {'15-24 years': 1.16,
#    '25-34 years': 1.25,
#    '35-54 years': 4.19,
#    '5-14 years': 0.0,
#    '55-74 years': 2.68,
#    '75+ years': 2.04},
#   'both': {'all ages': 3.12}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1991,
#   'male': {'15-24 years': 2.03,
#    '25-34 years': 6.37,
#    '35-54 years': 4.02,
#    '5-14 years': 0.0,
#    '55-74 years': 4.43,
#    '75+ years': 17.36},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 1.17,
#    '35-54 years': 2.27,
#    '5-14 years': 0.0,
#    '55-74 years': 4.44,
#    '75+ years': 3.78},
#   'both': {'all ages': 2.48}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1992,
#   'male': {'15-24 years': 3.0,
#    '25-34 years': 4.8,
#    '35-54 years': 6.1,
#    '5-14 years': 0.0,
#    '55-74 years': 6.97,
#    '75+ years': 10.64},
#   'female': {'15-24 years': 0.34,
#    '25-34 years': 0.0,
#    '35-54 years': 1.46,
#    '5-14 years': 0.0,
#    '55-74 years': 3.8,
#    '75+ years': 3.75},
#   'both': {'all ages': 2.51}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1993,
#   'male': {'15-24 years': 2.3,
#    '25-34 years': 5.56,
#    '35-54 years': 6.72,
#    '5-14 years': 0.0,
#    '55-74 years': 8.83,
#    '75+ years': 7.04},
#   'female': {'15-24 years': 1.02,
#    '25-34 years': 1.79,
#    '35-54 years': 1.42,
#    '5-14 years': 0.0,
#    '55-74 years': 5.07,
#    '75+ years': 11.3},
#   'both': {'all ages': 3.15}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1994,
#   'male': {'15-24 years': 1.95,
#    '25-34 years': 3.37,
#    '35-54 years': 8.1,
#    '5-14 years': 0.52,
#    '55-74 years': 8.49,
#    '75+ years': 24.82},
#   'female': {'15-24 years': 1.34,
#    '25-34 years': 0.31,
#    '35-54 years': 1.6,
#    '5-14 years': 0.27,
#    '55-74 years': 6.29,
#    '75+ years': 9.67},
#   'both': {'all ages': 3.29}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1995,
#   'male': {'15-24 years': 3.19,
#    '25-34 years': 7.25,
#    '35-54 years': 8.1,
#    '5-14 years': 0.26,
#    '55-74 years': 11.97,
#    '75+ years': 7.14},
#   'female': {'15-24 years': 0.99,
#    '25-34 years': 3.51,
#    '35-54 years': 1.76,
#    '5-14 years': 0.0,
#    '55-74 years': 3.73,
#    '75+ years': 3.89},
#   'both': {'all ages': 3.78}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1996,
#   'male': {'15-24 years': 1.25,
#    '25-34 years': 4.57,
#    '35-54 years': 5.86,
#    '5-14 years': 0.26,
#    '55-74 years': 7.31,
#    '75+ years': 10.75},
#   'female': {'15-24 years': 0.32,
#    '25-34 years': 1.0,
#    '35-54 years': 1.49,
#    '5-14 years': 0.27,
#    '55-74 years': 3.97,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.5}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1997,
#   'male': {'15-24 years': 1.22,
#    '25-34 years': 3.19,
#    '35-54 years': 6.1,
#    '5-14 years': 0.26,
#    '55-74 years': 8.53,
#    '75+ years': 3.51},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.34,
#    '35-54 years': 0.61,
#    '5-14 years': 0.0,
#    '55-74 years': 2.63,
#    '75+ years': 5.84},
#   'both': {'all ages': 2.18}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1998,
#   'male': {'15-24 years': 1.19,
#    '25-34 years': 2.14,
#    '35-54 years': 4.49,
#    '5-14 years': 0.0,
#    '55-74 years': 6.58,
#    '75+ years': 6.76},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.35,
#    '35-54 years': 1.77,
#    '5-14 years': 0.27,
#    '55-74 years': 1.99,
#    '75+ years': 1.88},
#   'both': {'all ages': 1.85}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 1999,
#   'male': {'15-24 years': 1.74,
#    '25-34 years': 2.14,
#    '35-54 years': 4.74,
#    '5-14 years': 0.0,
#    '55-74 years': 6.3,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.7,
#    '35-54 years': 0.75,
#    '5-14 years': 0.0,
#    '55-74 years': 3.03,
#    '75+ years': 5.28},
#   'both': {'all ages': 1.87}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2000,
#   'male': {'15-24 years': 1.68,
#    '25-34 years': 1.76,
#    '35-54 years': 3.74,
#    '5-14 years': 0.0,
#    '55-74 years': 5.98,
#    '75+ years': 10.64},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 1.43,
#    '35-54 years': 0.18,
#    '5-14 years': 0.0,
#    '55-74 years': 1.37,
#    '75+ years': 7.52},
#   'both': {'all ages': 1.69}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2001,
#   'male': {'15-24 years': 1.11,
#    '25-34 years': 0.7,
#    '35-54 years': 3.85,
#    '5-14 years': 0.89,
#    '55-74 years': 7.47,
#    '75+ years': 7.46},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.36,
#    '35-54 years': 0.53,
#    '5-14 years': 0.0,
#    '55-74 years': 1.38,
#    '75+ years': 6.03},
#   'both': {'all ages': 1.66}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2002,
#   'male': {'15-24 years': 1.7,
#    '25-34 years': 5.81,
#    '35-54 years': 5.26,
#    '5-14 years': 0.34,
#    '55-74 years': 9.67,
#    '75+ years': 10.32},
#   'female': {'15-24 years': 0.34,
#    '25-34 years': 0.45,
#    '35-54 years': 1.28,
#    '5-14 years': 0.0,
#    '55-74 years': 1.19,
#    '75+ years': 1.71},
#   'both': {'all ages': 2.45}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2003,
#   'male': {'15-24 years': 0.33,
#    '25-34 years': 4.75,
#    '35-54 years': 4.96,
#    '5-14 years': 0.35,
#    '55-74 years': 7.21,
#    '75+ years': 9.23},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.63,
#    '5-14 years': 0.0,
#    '55-74 years': 1.2,
#    '75+ years': 4.77},
#   'both': {'all ages': 1.95}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2006,
#   'male': {'15-24 years': 3.62,
#    '25-34 years': 3.19,
#    '35-54 years': 4.63,
#    '5-14 years': 0.45,
#    '55-74 years': 11.38,
#    '75+ years': 12.47},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.93,
#    '35-54 years': 1.11,
#    '5-14 years': 0.0,
#    '55-74 years': 3.35,
#    '75+ years': 2.54},
#   'both': {'all ages': 2.82}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2007,
#   'male': {'15-24 years': 2.57,
#    '25-34 years': 2.09,
#    '35-54 years': 5.25,
#    '5-14 years': 0.47,
#    '55-74 years': 7.02,
#    '75+ years': 14.2},
#   'female': {'15-24 years': 1.04,
#    '25-34 years': 0.0,
#    '35-54 years': 1.8,
#    '5-14 years': 0.0,
#    '55-74 years': 3.32,
#    '75+ years': 1.26},
#   'both': {'all ages': 2.6}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2008,
#   'male': {'15-24 years': 0.94,
#    '25-34 years': 1.6,
#    '35-54 years': 2.56,
#    '5-14 years': 0.45,
#    '55-74 years': 9.05,
#    '75+ years': 14.93},
#   'female': {'15-24 years': 0.32,
#    '25-34 years': 0.79,
#    '35-54 years': 2.09,
#    '5-14 years': 0.5,
#    '55-74 years': 1.92,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.07}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2009,
#   'male': {'15-24 years': 1.92,
#    '25-34 years': 1.01,
#    '35-54 years': 4.83,
#    '5-14 years': 0.0,
#    '55-74 years': 5.8,
#    '75+ years': 15.76},
#   'female': {'15-24 years': 0.36,
#    '25-34 years': 0.87,
#    '35-54 years': 0.69,
#    '5-14 years': 0.0,
#    '55-74 years': 1.21,
#    '75+ years': 1.25},
#   'both': {'all ages': 1.97}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2010,
#   'male': {'15-24 years': 3.17,
#    '25-34 years': 4.93,
#    '35-54 years': 4.33,
#    '5-14 years': 1.04,
#    '55-74 years': 6.73,
#    '75+ years': 11.47},
#   'female': {'15-24 years': 0.74,
#    '25-34 years': 0.42,
#    '35-54 years': 1.17,
#    '5-14 years': 1.2,
#    '55-74 years': 2.76,
#    '75+ years': 2.45},
#   'both': {'all ages': 2.73}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2011,
#   'male': {'15-24 years': 2.85,
#    '25-34 years': 3.81,
#    '35-54 years': 6.74,
#    '5-14 years': 0.0,
#    '55-74 years': 5.64,
#    '75+ years': 3.6},
#   'female': {'15-24 years': 1.54,
#    '25-34 years': 0.0,
#    '35-54 years': 0.71,
#    '5-14 years': 0.0,
#    '55-74 years': 1.17,
#    '75+ years': 6.92},
#   'both': {'all ages': 2.51}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2012,
#   'male': {'15-24 years': 1.96,
#    '25-34 years': 4.48,
#    '35-54 years': 6.9,
#    '5-14 years': 0.52,
#    '55-74 years': 5.18,
#    '75+ years': 8.83},
#   'female': {'15-24 years': 0.78,
#    '25-34 years': 1.54,
#    '35-54 years': 1.63,
#    '5-14 years': 0.0,
#    '55-74 years': 1.46,
#    '75+ years': 3.29},
#   'both': {'all ages': 2.81}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2013,
#   'male': {'15-24 years': 0.82,
#    '25-34 years': 3.59,
#    '35-54 years': 3.51,
#    '5-14 years': 0.52,
#    '55-74 years': 5.04,
#    '75+ years': 11.94},
#   'female': {'15-24 years': 0.41,
#    '25-34 years': 0.0,
#    '35-54 years': 1.42,
#    '5-14 years': 0.0,
#    '55-74 years': 3.92,
#    '75+ years': 6.31},
#   'both': {'all ages': 2.38}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2014,
#   'male': {'15-24 years': 1.3,
#    '25-34 years': 2.37,
#    '35-54 years': 3.58,
#    '5-14 years': 0.0,
#    '55-74 years': 5.35,
#    '75+ years': 14.97},
#   'female': {'15-24 years': 0.88,
#    '25-34 years': 0.0,
#    '35-54 years': 0.48,
#    '5-14 years': 0.58,
#    '55-74 years': 1.38,
#    '75+ years': 6.12},
#   'both': {'all ages': 2.07}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2015,
#   'male': {'15-24 years': 0.92,
#    '25-34 years': 3.91,
#    '35-54 years': 4.21,
#    '5-14 years': 0.0,
#    '55-74 years': 6.92,
#    '75+ years': 19.56},
#   'female': {'15-24 years': 1.42,
#    '25-34 years': 0.73,
#    '35-54 years': 0.97,
#    '5-14 years': 0.0,
#    '55-74 years': 1.68,
#    '75+ years': 4.96},
#   'both': {'all ages': 2.65}},
#  {'country': 'Armenia',
#   'code': 'ARM',
#   'year': 2016,
#   'male': {'15-24 years': 2.47,
#    '25-34 years': 1.56,
#    '35-54 years': 4.56,
#    '55-74 years': 6.73,
#    '75+ years': 19.37},
#   'female': {'15-24 years': 0.51,
#    '25-34 years': 0.72,
#    '35-54 years': 0.74,
#    '55-74 years': 1.95,
#    '75+ years': 1.95},
#   'both': {'all ages': 2.79}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 1995,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 53.19,
#    '35-54 years': 8.41,
#    '5-14 years': 0.0,
#    '55-74 years': 21.94,
#    '75+ years': 224.97},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 10.87}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 1999,
#   'male': {'15-24 years': 36.85,
#    '25-34 years': 56.89,
#    '35-54 years': 21.73,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 10.98}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2000,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 43.94,
#    '35-54 years': 14.06,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 101.11},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 12.8,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 133.42},
#   'both': {'all ages': 11.92}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2001,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 27.28,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 4.65}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2002,
#   'male': {'15-24 years': 16.84,
#    '25-34 years': 30.96,
#    '35-54 years': 13.26,
#    '5-14 years': 0.0,
#    '55-74 years': 65.4,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 10.19}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2003,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 12.93,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 2.21}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2004,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 16.22,
#    '35-54 years': 12.67,
#    '5-14 years': 0.0,
#    '55-74 years': 44.76,
#    '75+ years': 88.03},
#   'female': {'15-24 years': 15.04,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 8.66}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2005,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 18.74,
#    '5-14 years': 0.0,
#    '55-74 years': 28.62,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 14.61,
#    '25-34 years': 14.28,
#    '35-54 years': 11.04,
#    '5-14 years': 0.0,
#    '55-74 years': 12.29,
#    '75+ years': 0.0},
#   'both': {'all ages': 10.67}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2006,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 66.73,
#    '35-54 years': 18.65,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 10.93,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 9.52}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2007,
#   'male': {'15-24 years': 15.53,
#    '25-34 years': 33.7,
#    '35-54 years': 18.7,
#    '5-14 years': 0.0,
#    '55-74 years': 13.09,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 11.17,
#    '75+ years': 0.0},
#   'both': {'all ages': 8.44}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2008,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 17.1,
#    '35-54 years': 6.28,
#    '5-14 years': 0.0,
#    '55-74 years': 12.56,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 5.5,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 4.22}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2009,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 17.46,
#    '35-54 years': 12.71,
#    '5-14 years': 0.0,
#    '55-74 years': 12.06,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 4.22}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2010,
#   'male': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 25.74,
#    '5-14 years': 0.0,
#    '55-74 years': 23.09,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 9.82,
#    '75+ years': 0.0},
#   'both': {'all ages': 7.37}},
#  {'country': 'Aruba',
#   'code': 'ABW',
#   'year': 2011,
#   'male': {'15-24 years': 14.91,
#    '25-34 years': 0.0,
#    '35-54 years': 19.5,
#    '5-14 years': 0.0,
#    '55-74 years': 33.56,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 15.96,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 9.49,
#    '75+ years': 0.0},
#   'both': {'all ages': 9.43}},
#  {'country': 'Australia',
#   'code': 'AUS',
#   'year': 1985,
#   'male': {'15-24 years': 23.23,
#    '25-34 years': 27.48,
#    '35-54 years': 21.55,
#    '5-14 years': 0.31,
#    '55-74 years': 23.95,
#    '75+ years': 30.59},
#   'female': {'15-24 years': 5.29,
#    '25-34 years': 5.02,
#    '35-54 years': 7.8,
#    '5-14 years': 0.32,
#    '55-74 years': 8.47,
#    '75+ years': 9.4},
#   'both': {'all ages': 12.78}},
#  {'country': 'Australia',
#   'code': 'AUS',
#   'year': 1986,
#   'male': {'15-24 years': 21.62,
#    '25-34 years': 27.86,
#    '35-54 years': 24.7,
#    '5-14 years': 1.41,
#    '55-74 years': 26.74,
#    '75+ years': 38.08},
#   'female': {'15-24 years': 5.86,
#    '25-34 years': 6.77,
#    '35-54 years': 8.95,
#    '5-14 years': 0.08,
#    '55-74 years': 8.04,
#    '75+ years': 5.68},
#   'both': {'all ages': 13.8}},
#  {'country': 'Australia',
#   'code': 'AUS',
#   'year': 1987,
#   'male': {'15-24 years': 25.58,
#    '25-34 years': 27.79,
#    '35-54 years': 27.28,
#    '5-14 years': 0.47,
#    '55-74 years': 26.73,
#    '75+ years': 45.34},
#   'female': {'15-24 years': 5.49,
#    '25-34 years': 5.27,
#    '35-54 years': 7.43,
#    '5-14 years': 0.08,
#    '55-74 years': 8.34,
#    '75+ years': 9.02},
#   'both': {'all ages': 14.38}},
#  {'country': 'Australia',
#   'code': 'AUS',
#   'year': 1988,
#   'male': {'15-24 years': 26.22,
#    '25-34 years': 28.94,
#    '35-54 years': 25.37,
#    '5-14 years': 0.47,
#    '55-74 years': 25.55,
#    '75+ years': 36.27},
#   'female': {'15-24 years': 3.95,
#    '25-34 years': 7.82,
#    '35-54 years': 7.78,
#    '5-14 years': 0.08,
#    '55-74 years': 7.74,
#    '75+ years': 9.13},
#   'both': {'all ages': 14.18}},
#  {'country': 'Australia',
#   'code': 'AUS',
#   'year': 1989,
#   'male': {'15-24 years': 25.23,
# ...
#    '35-54 years': 72.1,
#    '5-14 years': 0.67,
#    '55-74 years': 65.99,
#    '75+ years': 121.11},
#   'female': {'15-24 years': 3.61,
#    '25-34 years': 5.38,
#    '35-54 years': 17.07,
#    '5-14 years': 0.53,
#    '55-74 years': 15.21,
#    '75+ years': 34.59},
#   'both': {'all ages': 29.33}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2003,
#   'male': {'15-24 years': 14.4,
#    '25-34 years': 28.9,
#    '35-54 years': 68.15,
#    '5-14 years': 1.37,
#    '55-74 years': 72.57,
#    '75+ years': 110.39},
#   'female': {'15-24 years': 3.42,
#    '25-34 years': 4.27,
#    '35-54 years': 14.59,
#    '5-14 years': 0.0,
#    '55-74 years': 17.88,
#    '75+ years': 36.1},
#   'both': {'all ages': 29.01}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2004,
#   'male': {'15-24 years': 16.25,
#    '25-34 years': 28.79,
#    '35-54 years': 67.87,
#    '5-14 years': 0.88,
#    '55-74 years': 60.54,
#    '75+ years': 120.1},
#   'female': {'15-24 years': 3.2,
#    '25-34 years': 5.76,
#    '35-54 years': 16.87,
#    '5-14 years': 0.37,
#    '55-74 years': 16.43,
#    '75+ years': 32.41},
#   'both': {'all ages': 28.47}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2005,
#   'male': {'15-24 years': 11.95,
#    '25-34 years': 26.34,
#    '35-54 years': 66.54,
#    '5-14 years': 0.9,
#    '55-74 years': 60.11,
#    '75+ years': 120.75},
#   'female': {'15-24 years': 2.64,
#    '25-34 years': 4.83,
#    '35-54 years': 14.95,
#    '5-14 years': 0.0,
#    '55-74 years': 16.72,
#    '75+ years': 26.28},
#   'both': {'all ages': 27.26}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2006,
#   'male': {'15-24 years': 12.73,
#    '25-34 years': 23.9,
#    '35-54 years': 60.36,
#    '5-14 years': 0.37,
#    '55-74 years': 59.94,
#    '75+ years': 89.86},
#   'female': {'15-24 years': 2.36,
#    '25-34 years': 6.59,
#    '35-54 years': 15.97,
#    '5-14 years': 0.19,
#    '55-74 years': 15.27,
#    '75+ years': 25.12},
#   'both': {'all ages': 25.66}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2007,
#   'male': {'15-24 years': 11.8,
#    '25-34 years': 23.17,
#    '35-54 years': 57.96,
#    '5-14 years': 0.38,
#    '55-74 years': 61.13,
#    '75+ years': 109.34},
#   'female': {'15-24 years': 1.91,
#    '25-34 years': 4.06,
#    '35-54 years': 13.87,
#    '5-14 years': 0.0,
#    '55-74 years': 16.11,
#    '75+ years': 27.59},
#   'both': {'all ages': 25.59}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2008,
#   'male': {'15-24 years': 11.77,
#    '25-34 years': 22.43,
#    '35-54 years': 58.35,
#    '5-14 years': 0.77,
#    '55-74 years': 62.73,
#    '75+ years': 112.56},
#   'female': {'15-24 years': 2.9,
#    '25-34 years': 5.11,
#    '35-54 years': 13.77,
#    '5-14 years': 0.0,
#    '55-74 years': 14.98,
#    '75+ years': 26.31},
#   'both': {'all ages': 25.92}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2009,
#   'male': {'15-24 years': 17.3,
#    '25-34 years': 23.42,
#    '35-54 years': 56.98,
#    '5-14 years': 0.59,
#    '55-74 years': 63.67,
#    '75+ years': 90.54},
#   'female': {'15-24 years': 3.09,
#    '25-34 years': 5.45,
#    '35-54 years': 13.73,
#    '5-14 years': 0.82,
#    '55-74 years': 16.69,
#    '75+ years': 18.44},
#   'both': {'all ages': 25.8}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2010,
#   'male': {'15-24 years': 12.13,
#    '25-34 years': 24.33,
#    '35-54 years': 55.88,
#    '5-14 years': 0.4,
#    '55-74 years': 68.23,
#    '75+ years': 101.57},
#   'female': {'15-24 years': 3.29,
#    '25-34 years': 4.94,
#    '35-54 years': 12.26,
#    '5-14 years': 0.21,
#    '55-74 years': 16.23,
#    '75+ years': 21.84},
#   'both': {'all ages': 26.16}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2011,
#   'male': {'15-24 years': 13.95,
#    '25-34 years': 22.81,
#    '35-54 years': 54.8,
#    '5-14 years': 0.6,
#    '55-74 years': 63.08,
#    '75+ years': 83.51},
#   'female': {'15-24 years': 2.69,
#    '25-34 years': 3.02,
#    '35-54 years': 13.11,
#    '5-14 years': 0.63,
#    '55-74 years': 17.44,
#    '75+ years': 24.21},
#   'both': {'all ages': 25.49}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2012,
#   'male': {'15-24 years': 13.25,
#    '25-34 years': 21.59,
#    '35-54 years': 48.92,
#    '5-14 years': 0.4,
#    '55-74 years': 62.39,
#    '75+ years': 100.1},
#   'female': {'15-24 years': 2.56,
#    '25-34 years': 4.21,
#    '35-54 years': 11.36,
#    '5-14 years': 0.0,
#    '55-74 years': 16.3,
#    '75+ years': 24.88},
#   'both': {'all ages': 24.85}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2013,
#   'male': {'15-24 years': 9.86,
#    '25-34 years': 16.09,
#    '35-54 years': 43.48,
#    '5-14 years': 0.0,
#    '55-74 years': 57.25,
#    '75+ years': 85.61},
#   'female': {'15-24 years': 2.08,
#    '25-34 years': 4.82,
#    '35-54 years': 10.94,
#    '5-14 years': 0.21,
#    '55-74 years': 14.82,
#    '75+ years': 21.07},
#   'both': {'all ages': 22.18}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2014,
#   'male': {'15-24 years': 12.09,
#    '25-34 years': 20.06,
#    '35-54 years': 34.81,
#    '5-14 years': 0.4,
#    '55-74 years': 56.42,
#    '75+ years': 75.28},
#   'female': {'15-24 years': 1.42,
#    '25-34 years': 3.69,
#    '35-54 years': 10.68,
#    '5-14 years': 0.0,
#    '55-74 years': 13.54,
#    '75+ years': 15.92},
#   'both': {'all ages': 20.45}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2015,
#   'male': {'15-24 years': 11.85,
#    '25-34 years': 20.23,
#    '35-54 years': 32.94,
#    '5-14 years': 0.4,
#    '55-74 years': 46.55,
#    '75+ years': 91.42},
#   'female': {'15-24 years': 2.72,
#    '25-34 years': 4.42,
#    '35-54 years': 9.23,
#    '5-14 years': 0.21,
#    '55-74 years': 13.4,
#    '75+ years': 23.9},
#   'both': {'all ages': 19.89}},
#  {'country': 'Hungary',
#   'code': 'HUN',
#   'year': 2016,
#   'male': {'15-24 years': 10.21,
#    '25-34 years': 15.48,
#    '35-54 years': 31.27,
#    '55-74 years': 46.51,
#    '75+ years': 86.84},
#   'female': {'15-24 years': 2.61,
#    '25-34 years': 4.98,
#    '35-54 years': 8.45,
#    '55-74 years': 11.96,
#    '75+ years': 23.03},
#   'both': {'all ages': 20.99}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1985,
#   'male': {'15-24 years': 31.96,
#    '25-34 years': 24.39,
#    '35-54 years': 27.13,
#    '5-14 years': 0.0,
#    '55-74 years': 30.49,
#    '75+ years': 22.22},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 12.0,
#    '5-14 years': 0.0,
#    '55-74 years': 22.86,
#    '75+ years': 0.0},
#   'both': {'all ages': 14.54}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1986,
#   'male': {'15-24 years': 23.04,
#    '25-34 years': 28.99,
#    '35-54 years': 30.3,
#    '5-14 years': 4.61,
#    '55-74 years': 23.95,
#    '75+ years': 22.73},
#   'female': {'15-24 years': 4.78,
#    '25-34 years': 5.1,
#    '35-54 years': 11.76,
#    '5-14 years': 0.0,
#    '55-74 years': 28.09,
#    '75+ years': 31.75},
#   'both': {'all ages': 16.64}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1987,
#   'male': {'15-24 years': 18.43,
#    '25-34 years': 18.96,
#    '35-54 years': 22.14,
#    '5-14 years': 4.59,
#    '55-74 years': 29.41,
#    '75+ years': 43.48},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 10.05,
#    '35-54 years': 7.63,
#    '5-14 years': 0.0,
#    '55-74 years': 55.25,
#    '75+ years': 0.0},
#   'both': {'all ages': 15.96}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1988,
#   'male': {'15-24 years': 36.53,
#    '25-34 years': 18.6,
#    '35-54 years': 39.29,
#    '5-14 years': 0.0,
#    '55-74 years': 40.7,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 4.85,
#    '35-54 years': 7.43,
#    '5-14 years': 0.0,
#    '55-74 years': 5.43,
#    '75+ years': 15.15},
#   'both': {'all ages': 15.27}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1989,
#   'male': {'15-24 years': 27.52,
#    '25-34 years': 9.22,
#    '35-54 years': 20.62,
#    '5-14 years': 0.0,
#    '55-74 years': 11.43,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 4.78,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 21.62,
#    '75+ years': 14.93},
#   'both': {'all ages': 9.48}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1990,
#   'male': {'15-24 years': 46.73,
#    '25-34 years': 41.47,
#    '35-54 years': 26.85,
#    '5-14 years': 0.0,
#    '55-74 years': 45.2,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 4.83,
#    '25-34 years': 4.74,
#    '35-54 years': 10.49,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 0.0},
#   'both': {'all ages': 17.15}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1991,
#   'male': {'15-24 years': 61.03,
#    '25-34 years': 13.7,
#    '35-54 years': 19.42,
#    '5-14 years': 0.0,
#    '55-74 years': 28.25,
#    '75+ years': 41.67},
#   'female': {'15-24 years': 4.85,
#    '25-34 years': 0.0,
#    '35-54 years': 10.17,
#    '5-14 years': 4.85,
#    '55-74 years': 15.79,
#    '75+ years': 0.0},
#   'both': {'all ages': 15.68}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1992,
#   'male': {'15-24 years': 18.87,
#    '25-34 years': 41.1,
#    '35-54 years': 18.81,
#    '5-14 years': 0.0,
#    '55-74 years': 22.35,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 4.67,
#    '35-54 years': 6.56,
#    '5-14 years': 0.0,
#    '55-74 years': 10.53,
#    '75+ years': 0.0},
#   'both': {'all ages': 11.76}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1993,
#   'male': {'15-24 years': 23.81,
#    '25-34 years': 13.82,
#    '35-54 years': 21.34,
#    '5-14 years': 0.0,
#    '55-74 years': 22.1,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 4.72,
#    '35-54 years': 12.7,
#    '5-14 years': 0.0,
#    '55-74 years': 10.53,
#    '75+ years': 0.0},
#   'both': {'all ages': 10.81}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1994,
#   'male': {'15-24 years': 23.7,
#    '25-34 years': 18.6,
#    '35-54 years': 23.67,
#    '5-14 years': 0.0,
#    '55-74 years': 21.98,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 4.88,
#    '25-34 years': 0.0,
#    '35-54 years': 0.0,
#    '5-14 years': 0.0,
#    '55-74 years': 5.21,
#    '75+ years': 27.4},
#   'both': {'all ages': 10.3}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1995,
#   'male': {'15-24 years': 18.78,
#    '25-34 years': 38.1,
#    '35-54 years': 14.33,
#    '5-14 years': 0.0,
#    '55-74 years': 27.32,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 9.66,
#    '35-54 years': 2.99,
#    '5-14 years': 0.0,
#    '55-74 years': 5.15,
#    '75+ years': 13.33},
#   'both': {'all ages': 11.03}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1996,
#   'male': {'15-24 years': 18.6,
#    '25-34 years': 43.9,
#    '35-54 years': 22.41,
#    '5-14 years': 4.57,
#    '55-74 years': 21.86,
#    '75+ years': 37.04},
#   'female': {'15-24 years': 4.83,
#    '25-34 years': 0.0,
#    '35-54 years': 5.83,
#    '5-14 years': 0.0,
#    '55-74 years': 5.15,
#    '75+ years': 13.16},
#   'both': {'all ages': 13.39}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1997,
#   'male': {'15-24 years': 13.85,
#    '25-34 years': 14.68,
#    '35-54 years': 27.34,
#    '5-14 years': 0.0,
#    '55-74 years': 43.12,
#    '75+ years': 36.84},
#   'female': {'15-24 years': 9.64,
#    '25-34 years': 4.93,
#    '35-54 years': 8.53,
#    '5-14 years': 0.0,
#    '55-74 years': 5.09,
#    '75+ years': 0.0},
#   'both': {'all ages': 13.26}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1998,
#   'male': {'15-24 years': 23.08,
#    '25-34 years': 19.43,
#    '35-54 years': 24.06,
#    '5-14 years': 0.0,
#    '55-74 years': 21.13,
#    '75+ years': 17.99},
#   'female': {'15-24 years': 4.82,
#    '25-34 years': 9.8,
#    '35-54 years': 8.31,
#    '5-14 years': 0.0,
#    '55-74 years': 0.0,
#    '75+ years': 12.47},
#   'both': {'all ages': 11.89}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 1999,
#   'male': {'15-24 years': 18.47,
#    '25-34 years': 19.32,
#    '35-54 years': 36.47,
#    '5-14 years': 0.0,
#    '55-74 years': 5.21,
#    '75+ years': 17.49},
#   'female': {'15-24 years': 9.54,
#    '25-34 years': 9.84,
#    '35-54 years': 2.7,
#    '5-14 years': 0.0,
#    '55-74 years': 9.88,
#    '75+ years': 0.0},
#   'both': {'all ages': 12.12}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2000,
#   'male': {'15-24 years': 59.83,
#    '25-34 years': 62.35,
#    '35-54 years': 25.63,
#    '5-14 years': 0.0,
#    '55-74 years': 30.35,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 4.74,
#    '25-34 years': 0.0,
#    '35-54 years': 10.56,
#    '5-14 years': 0.0,
#    '55-74 years': 14.53,
#    '75+ years': 0.0},
#   'both': {'all ages': 19.25}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2001,
#   'male': {'15-24 years': 36.85,
#    '25-34 years': 23.68,
#    '35-54 years': 22.63,
#    '5-14 years': 0.0,
#    '55-74 years': 19.74,
#    '75+ years': 32.78},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 9.71,
#    '35-54 years': 12.92,
#    '5-14 years': 0.0,
#    '55-74 years': 4.75,
#    '75+ years': 0.0},
#   'both': {'all ages': 13.65}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2002,
#   'male': {'15-24 years': 13.88,
#    '25-34 years': 33.34,
#    '35-54 years': 9.93,
#    '5-14 years': 0.0,
#    '55-74 years': 28.77,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 4.74,
#    '25-34 years': 9.76,
#    '35-54 years': 10.14,
#    '5-14 years': 0.0,
#    '55-74 years': 9.31,
#    '75+ years': 11.37},
#   'both': {'all ages': 11.26}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2003,
#   'male': {'15-24 years': 22.88,
#    '25-34 years': 4.81,
#    '35-54 years': 19.75,
#    '5-14 years': 0.0,
#    '55-74 years': 27.95,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 4.93,
#    '35-54 years': 2.51,
#    '5-14 years': 0.0,
#    '55-74 years': 18.14,
#    '75+ years': 0.0},
#   'both': {'all ages': 9.69}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2004,
#   'male': {'15-24 years': 27.28,
#    '25-34 years': 18.95,
#    '35-54 years': 21.82,
#    '5-14 years': 0.0,
#    '55-74 years': 18.05,
#    '75+ years': 44.64},
#   'female': {'15-24 years': 4.74,
#    '25-34 years': 19.49,
#    '35-54 years': 4.98,
#    '5-14 years': 0.0,
#    '55-74 years': 8.86,
#    '75+ years': 0.0},
#   'both': {'all ages': 12.89}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2005,
#   'male': {'15-24 years': 13.57,
#    '25-34 years': 27.82,
#    '35-54 years': 24.07,
#    '5-14 years': 0.0,
#    '55-74 years': 21.8,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 14.8,
#    '5-14 years': 0.0,
#    '55-74 years': 12.94,
#    '75+ years': 0.0},
#   'both': {'all ages': 12.0}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2006,
#   'male': {'15-24 years': 26.35,
#    '25-34 years': 8.64,
#    '35-54 years': 22.72,
#    '5-14 years': 0.0,
#    '55-74 years': 16.8,
#    '75+ years': 0.0},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 4.62,
#    '35-54 years': 14.65,
#    '5-14 years': 0.0,
#    '55-74 years': 12.61,
#    '75+ years': 0.0},
#   'both': {'all ages': 11.31}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2007,
#   'male': {'15-24 years': 30.13,
#    '25-34 years': 24.54,
#    '35-54 years': 26.26,
#    '5-14 years': 0.0,
#    '55-74 years': 8.11,
#    '75+ years': 40.25},
#   'female': {'15-24 years': 4.53,
#    '25-34 years': 9.05,
#    '35-54 years': 2.4,
#    '5-14 years': 0.0,
#    '55-74 years': 8.18,
#    '75+ years': 9.84},
#   'both': {'all ages': 12.77}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2008,
#   'male': {'15-24 years': 16.57,
#    '25-34 years': 19.46,
#    '35-54 years': 21.52,
#    '5-14 years': 0.0,
#    '55-74 years': 27.41,
#    '75+ years': 13.15},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 8.77,
#    '35-54 years': 9.41,
#    '5-14 years': 0.0,
#    '55-74 years': 19.8,
#    '75+ years': 0.0},
#   'both': {'all ages': 12.8}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2009,
#   'male': {'15-24 years': 8.34,
#    '25-34 years': 24.28,
#    '35-54 years': 22.32,
#    '5-14 years': 0.0,
#    '55-74 years': 38.07,
#    '75+ years': 12.84},
#   'female': {'15-24 years': 0.0,
#    '25-34 years': 0.0,
#    '35-54 years': 14.04,
#    '5-14 years': 0.0,
#    '55-74 years': 3.84,
#    '75+ years': 0.0},
#   'both': {'all ages': 12.15}},
#  {'country': 'Iceland',
#   'code': 'ISL',
#   'year': 2010,
#   'male': {'15-24 years': 25.1,
#    '25-34 years': 33.88,
#    '35-54 years': 25.24,
#    '5-14 years': 4.56,
#    '55-74 years': 25.95,
#    '75+ years': 37.83},
#   'female': {'15-24 years': 4.37,
#    '25-34 years': 4.43,
#    '35-54 years': 11.76,
#    '5-14 years': 0.0,
#    '55-74 years': 11.15,
#    '75+ years': 0.0},
#   'both': {'all ages': 15.61}},
#  ...]

# %%
# Specify CSV file containing happiness data
sJSON_output = os.path.join(".","Data/suicide_data.json")

with open(sJSON_output, 'w') as f:
    json.dump(sJSON, f)

# %% [markdown]
# ### Gather financial data

# %%
# Pull data for financial indicators
financial_df = geoMaster[["Country","Code","year","HDI for year"," gdp_for_year ($) ","gdp_per_capita ($)"]]

# %%
# Change column name and remove extra weird spaces
financial_df = financial_df.rename(columns={" gdp_for_year ($) ":"gdp_for_year ($)"})

# %%
# Yearly data occurs many times, just provide a single occurence and drop duplicates
financial_df.drop_duplicates(inplace = True)
financial_df = financial_df.set_index(["Country","Code","year"])
financial_df
# Out:
#                       HDI for year gdp_for_year ($)  gdp_per_capita ($)
# Country    Code year
# Albania    ALB  1987           NaN    2,156,624,900                 796
#                 1988           NaN    2,126,000,000                 769
#                 1989           NaN    2,335,124,988                 833
#                 1992           NaN      709,452,584                 251
#                 1993           NaN    1,228,071,038                 437
# ...                            ...              ...                 ...
# Uzbekistan UZB  2010         0.655   39,332,770,929                1533
#                 2011         0.661   45,915,191,189                1767
#                 2012         0.668   51,821,573,338                1964
#                 2013         0.672   57,690,453,461                2150
#                 2014         0.675   63,067,077,179                2309
#
# [2321 rows x 3 columns]

# %%
# Pull the latest data for the provided financial indicators given the last year
# suicide years were recorded, per country
latestGDP = []
latestGDPcap = []
for i in countryLastDate.index:
    country = countryLastDate.loc[i]['Country']
    code = countryLastDate.loc[i]['Code']
    latest_year = countryLastDate.loc[i]['year']
    entry = financial_df.loc[(country, code, latest_year)]
    latestGDP.append(entry['gdp_for_year ($)'])
    latestGDPcap.append(entry['gdp_per_capita ($)'])

# %%
# Append financial data to current data
countryLastDate["gdp_for_year ($)"] = latestGDP
countryLastDate["gdp_per_capita ($)"] = latestGDPcap
countryLastDate
# Out:
#                                                Country Code  year  \
# 0                                              Albania  ALB  2010
# 1                                  Antigua and Barbuda  ATG  2015
# 2                                            Argentina  ARG  2015
# 3                                              Armenia  ARM  2016
# 4                                                Aruba  ABW  2011
# ..                                                 ...  ...   ...
# 96                                United Arab Emirates  ARE  2010
# 97   United Kingdom of Great Britain and Northern I...  GBR  2015
# 98                            United States of America  USA  2015
# 99                                             Uruguay  URY  2015
# 100                                         Uzbekistan  UZB  2014
#
#      suicides_no   population  total suicides/100k pop    gdp_for_year ($)  \
# 0           96.0    2736025.0                     3.51      11,926,953,259
# 1            1.0      91889.0                     1.09       1,364,863,037
# 2         3073.0   39699624.0                     7.74     594,749,285,413
# 3           67.0    2400033.0                     2.79      10,546,135,160
# 4            9.0      95488.0                     9.43       2,584,463,687
# ..           ...          ...                      ...                 ...
# 96         111.0    7839736.0                     1.42     289,787,338,325
# 97        4910.0   61082942.0                     8.04   2,885,570,309,161
# 98       44189.0  300078511.0                    14.73  18,120,714,000,000
# 99         630.0    3190795.0                    19.74      53,274,304,222
# 100       2095.0   27313507.0                     7.67      63,067,077,179
#
#      gdp_per_capita ($)
# 0                  4359
# 1                 14853
# 2                 14981
# 3                  3788
# 4                 27066
# ..                  ...
# 96                36964
# 97                47240
# 98                60387
# 99                16696
# 100                2309
#
# [101 rows x 8 columns]

# %%
# Construct financial data for 2015 and 2016
#fin2015 = financial_df.loc[financial_df["year"] == 2015][["Code","gdp_for_year ($)","gdp_per_capita ($)"]]
#fin2015 = fin2015.rename(columns={"gdp_for_year ($)":"gdp_for_2015 ($)","gdp_per_capita ($)":"gdp_per_capita_2015 ($)"})
#
#fin2016 = financial_df.loc[financial_df["year"] == 2016][["Code","gdp_for_year ($)","gdp_per_capita ($)"]]
#fin2016 = fin2016.rename(columns={"gdp_for_year ($)":"gdp_for_2016 ($)","gdp_per_capita ($)":"gdp_per_capita_2016 ($)"})

# %% [markdown]
# ### Gather happiness data

# %%
# Specify CSV file containing happiness data
happiness_2020 = os.path.join(".","Data/WHR20_DataForFigure2.1.csv")

# Import CSV file as Dataframe
happiness_2020_df = pd.read_csv(happiness_2020)

# %%
# Peek happiness data
happiness_2020_df
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# 2                          0.035014      7.628528      7.491272
# 3                          0.059616      7.621347      7.387653
# 4                          0.034837      7.556281      7.419719
# ..                              ...           ...           ...
# 148                        0.115183      3.701658      3.250141
# 149                        0.052425      3.415053      3.209547
# 150                        0.058674      3.414202      3.184198
# 151                        0.107610      3.027516      2.605684
# 152                        0.031311      2.628270      2.505530
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                10.639267        0.954330                71.900825
# 1                10.774001        0.955991                72.402504
# 2                10.979933        0.942847                74.102448
# 3                10.772559        0.974670                73.000000
# 4                11.087804        0.952487                73.200783
# ..                     ...             ...                      ...
# 148               6.625160        0.319460                45.200001
# 149               7.600104        0.540835                61.098846
# 150               7.865712        0.763093                55.617260
# 151               7.425360        0.553707                51.000000
# 152               7.462861        0.470367                52.590000
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                        0.949172   -0.059482                   0.195445
# 1                        0.951444    0.066202                   0.168489
# 2                        0.921337    0.105911                   0.303728
# 3                        0.948892    0.246944                   0.711710
# 4                        0.955750    0.134533                   0.263218
# ..                            ...         ...                        ...
# 148                      0.640881    0.082410                   0.891807
# 149                      0.900589    0.055484                   0.183541
# 150                      0.711458   -0.072064                   0.810237
# 151                      0.451314    0.016519                   0.763417
# 152                      0.396573   -0.096429                   0.933687
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                    1.972317                          1.285190
# 1                    1.972317                          1.326949
# 2                    1.972317                          1.390774
# 3                    1.972317                          1.326502
# 4                    1.972317                          1.424207
# ..                        ...                               ...
# 148                  1.972317                          0.041072
# 149                  1.972317                          0.343243
# 150                  1.972317                          0.425564
# 151                  1.972317                          0.289083
# 152                  1.972317                          0.300706
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                        1.499526                               0.961271
# 1                        1.503449                               0.979333
# 2                        1.472403                               1.040533
# 3                        1.547567                               1.000843
# 4                        1.495173                               1.008072
# ..                            ...                                    ...
# 148                      0.000000                               0.000000
# 149                      0.522876                               0.572383
# 150                      1.047835                               0.375038
# 151                      0.553279                               0.208809
# 152                      0.356434                               0.266052
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                      0.662317                  0.159670
# 1                                      0.665040                  0.242793
# 2                                      0.628954                  0.269056
# 3                                      0.661981                  0.362330
# 4                                      0.670201                  0.287985
# ..                                          ...                       ...
# 148                                    0.292814                  0.253513
# 149                                    0.604088                  0.235705
# 150                                    0.377405                  0.151349
# 151                                    0.065609                  0.209935
# 152                                    0.000000                  0.135235
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                   0.477857             2.762835
# 1                                   0.495260             2.432741
# 2                                   0.407946             2.350267
# 3                                   0.144541             2.460688
# 4                                   0.434101             2.168266
# ..                                       ...                  ...
# 148                                 0.028265             2.860198
# 149                                 0.485542             0.548445
# 150                                 0.080929             0.841031
# 151                                 0.111157             1.378751
# 152                                 0.001226             1.507236
#
# [153 rows x 20 columns]

# %%
# Only pull happiness ranking and score
happiness_2020_df= happiness_2020_df[["Country name","Regional indicator","Ladder score"]].reset_index()
happiness_2020_df
# Out:
#      index              Country name  Regional indicator  Ladder score
# 0        0                   Finland      Western Europe        7.8087
# 1        1                   Denmark      Western Europe        7.6456
# 2        2               Switzerland      Western Europe        7.5599
# 3        3                   Iceland      Western Europe        7.5045
# 4        4                    Norway      Western Europe        7.4880
# ..     ...                       ...                 ...           ...
# 148    148  Central African Republic  Sub-Saharan Africa        3.4759
# 149    149                    Rwanda  Sub-Saharan Africa        3.3123
# 150    150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151    151               South Sudan  Sub-Saharan Africa        2.8166
# 152    152               Afghanistan          South Asia        2.5669
#
# [153 rows x 4 columns]

# %%
# Rename columns
happiness_2020_df = happiness_2020_df.rename(columns={"index":"2020 Rank","Country name":"Country","Ladder score":"2020 Score","Regional indicator":"Region"})

# %%
# Make ranking start at 1st place (0th place, como que no...)
happiness_2020_df["2020 Rank"] +=1

# %%
# Rename columns prior to merging to current data
happiness_2020_df = happiness_2020_df[["Country","Region","2020 Rank","2020 Score"]]
happiness_2020_df
# Out:
#                       Country              Region  2020 Rank  2020 Score
# 0                     Finland      Western Europe          1      7.8087
# 1                     Denmark      Western Europe          2      7.6456
# 2                 Switzerland      Western Europe          3      7.5599
# 3                     Iceland      Western Europe          4      7.5045
# 4                      Norway      Western Europe          5      7.4880
# ..                        ...                 ...        ...         ...
# 148  Central African Republic  Sub-Saharan Africa        149      3.4759
# 149                    Rwanda  Sub-Saharan Africa        150      3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        151      3.2992
# 151               South Sudan  Sub-Saharan Africa        152      2.8166
# 152               Afghanistan          South Asia        153      2.5669
#
# [153 rows x 4 columns]

# %%
# Pull in country codes for countries listed in happiness report
happy2020master = happiness_2020_df.merge(raw_codes_df,on="Country",how="outer")
happy2020master
# Out:
#                                 Country          Region  2020 Rank  \
# 0                               Finland  Western Europe        1.0
# 1                               Denmark  Western Europe        2.0
# 2                           Switzerland  Western Europe        3.0
# 3                               Iceland  Western Europe        4.0
# 4                                Norway  Western Europe        5.0
# ..                                  ...             ...        ...
# 265                             Vanuatu             NaN        NaN
# 266  Venezuela (Bolivarian Republic of)             NaN        NaN
# 267                            Viet Nam             NaN        NaN
# 268                   Wallis and Futuna             NaN        NaN
# 269                      Western Sahara             NaN        NaN
#
#      2020 Score Code                     Location
# 0        7.8087  FIN                 [64.0, 26.0]
# 1        7.6456  DNK                 [56.0, 10.0]
# 2        7.5599  CHE                  [47.0, 8.0]
# 3        7.5045  ISL                [65.0, -18.0]
# 4        7.4880  NOR                 [62.0, 10.0]
# ..          ...  ...                          ...
# 265         NaN  VUT               [-16.0, 167.0]
# 266         NaN  VEN                 [8.0, -66.0]
# 267         NaN  VNM  [16.16666666, 107.83333333]
# 268         NaN  WLF              [-13.3, -176.2]
# 269         NaN  ESH                [24.5, -13.0]
#
# [270 rows x 6 columns]

# %%
# The following countries were not merged correctly (i.e., country names differ in spelling)
unfoundCountries3 = happy2020master.loc[pd.isnull(happy2020master["Code"])]
print(f"List of unmatched coutries:\n{unfoundCountries3['Country'].unique()}")
# Out:
# List of unmatched coutries:
# ['United Kingdom' 'United States' 'Taiwan Province of China' 'Kosovo'
#  'South Korea' 'Bolivia' 'Moldova' 'Russia' 'North Cyprus'
#  'Hong Kong S.A.R. of China' 'Vietnam' 'Ivory Coast' 'Congo (Brazzaville)'
#  'Macedonia' 'Venezuela' 'Laos' 'Iran' 'Palestinian Territories'
#  'Congo (Kinshasa)' 'Tanzania']

# %%
# Print list of troublesome countries (countries with no name matches)
print(raw_codes_df[raw_codes_df['Country'].str.contains("Iv")]["Country"])
# Out:
# 106    Côte d'Ivoire
# Name: Country, dtype: object

# %%
# Correct master data to facilitate finding ISO-codes
# North Cyprus not officially recognized == has no ISO Code
corrections3 = {"Moldova":"Moldova (Republic of)",
                "Russia":"Russian Federation",
                "Kosovo":"Republic of Kosovo",
                "Vietnam":"Viet Nam",
                "Macedonia":"Macedonia (the former Yugoslav Republic of)",
                "Laos":"Lao People's Democratic Republic",
                "Palestinian Territories":"Palestine, State of",
                "Iran":"Iran (Islamic Republic of)",
                "Congo (Kinshasa)":"Congo (Democratic Republic of the)",
                "Congo (Brazzaville)":"Congo",
                "Ivory Coast": "Côte d'Ivoire",
                "Tanzania":"Tanzania, United Republic of",
                "Bolivia":"Bolivia (Plurinational State of)",
                "South Korea":"Korea (Democratic People's Republic of)",
                "Venezuela": "Venezuela (Bolivarian Republic of)",
                "Taiwan Province of China":"Taiwan",
                "Hong Kong S.A.R. of China":"Hong Kong",
                "United Kingdom":"United Kingdom of Great Britain and Northern Ireland",
                "United States":"United States of America"}

# Make name corrections master data set
for country in corrections3:
    oldName = country
    newName = corrections3[country]
    happiness_2020_df.loc[happiness_2020_df["Country"] == oldName,"Country"] = newName

# %%
# Merge again after the corrections
happy2020master = happiness_2020_df.merge(raw_codes_df,on="Country",how="left")
happy2020master
# Out:
#                       Country              Region  2020 Rank  2020 Score Code  \
# 0                     Finland      Western Europe          1      7.8087  FIN
# 1                     Denmark      Western Europe          2      7.6456  DNK
# 2                 Switzerland      Western Europe          3      7.5599  CHE
# 3                     Iceland      Western Europe          4      7.5045  ISL
# 4                      Norway      Western Europe          5      7.4880  NOR
# ..                        ...                 ...        ...         ...  ...
# 148  Central African Republic  Sub-Saharan Africa        149      3.4759  CAF
# 149                    Rwanda  Sub-Saharan Africa        150      3.3123  RWA
# 150                  Zimbabwe  Sub-Saharan Africa        151      3.2992  ZWE
# 151               South Sudan  Sub-Saharan Africa        152      2.8166  SSD
# 152               Afghanistan          South Asia        153      2.5669  AFG
#
#           Location
# 0     [64.0, 26.0]
# 1     [56.0, 10.0]
# 2      [47.0, 8.0]
# 3    [65.0, -18.0]
# 4     [62.0, 10.0]
# ..             ...
# 148    [7.0, 21.0]
# 149   [-2.0, 30.0]
# 150  [-20.0, 30.0]
# 151    [7.0, 30.0]
# 152   [33.0, 65.0]
#
# [153 rows x 6 columns]

# %%
# The following countries were not merged correctly (i.e., country names differ in spelling)
unfoundCountries3 = happy2020master.loc[pd.isnull(happy2020master["Code"])]
print(f"List of unmatched coutries:\n{unfoundCountries3['Country'].unique()}")
# Out:
# List of unmatched coutries:
# ['North Cyprus']

# %%
# Merge happiness data into dataframe with latest data
uberSet = countryLastDate.merge(happy2020master,on="Code",how="left")
uberSet=uberSet.drop(columns=["Country_y"])

# %% [markdown]
# ### Complete data set!

# %%
# Drop missing happiness countries without suicide data
corrSet = uberSet.dropna(how="any")
corrSet = corrSet.rename(columns={"Country_x":"Country"})

# %%
# Specify CSV file containing happiness data
final_output = os.path.join(".","Data/latest_data_available.csv")

# Save CSV file with latest data for correlation
corrSet.to_csv(final_output)

# %% [markdown]
# ### Experimental: Pull suicide data using WHO API

# %%
# Use REST API to collect ISO3code listing for all countries
who_url = "https://ghoapi.azureedge.net/api/MH_12"

# Make JSON request to Rest Countries API
who_data = requests.get(who_url).json()

# Peek JSON formatted data
print(json.dumps(who_data,indent=4, sort_keys=True))
# Out:
# {
#     "@odata.context": "https://ghoapi.azureedge.net/api/$metadata#MH_12",
#     "value": [
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:39.997+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627179,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 1.7,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "1.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.03+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627180,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 8.1,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "8.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.06+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627181,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 14.3,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "14.3"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.09+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627182,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 2.1,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "2.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.113+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627183,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 7.4,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "7.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.147+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627184,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 12.5,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "12.5"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.17+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627185,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 2.1,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "2.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.197+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627186,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 6.6,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "6.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.217+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627187,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 10.9,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "10.9"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.24+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627188,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 2.1,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "2.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.263+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627189,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 6.4,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "6.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.283+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627190,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 10.6,
#             "SpatialDim": "AFG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "10.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.31+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627191,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 7.2,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "7.2"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.337+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627192,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 13.9,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "13.9"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.36+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627193,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 21.9,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "21.9"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.383+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627194,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 5.1,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "5.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.42+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627195,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 10.4,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "10.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.46+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627196,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 16.7,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "16.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.487+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627197,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 4.7,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "4.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.52+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627198,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 9.3,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "9.3"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.55+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627199,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 14.8,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "14.8"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.57+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627200,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 4.6,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "4.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.59+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627201,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 8.9,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "8.9"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.61+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627202,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 14.0,
#             "SpatialDim": "AGO",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "14"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.63+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627203,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.6,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "3.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.653+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627204,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 5.8,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "5.8"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.683+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627205,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 8.2,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "8.2"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.707+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627206,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 6.0,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.727+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627207,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 7.7,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "7.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.753+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627208,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 9.5,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "9.5"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.773+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627209,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 4.0,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.793+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627210,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 5.3,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "5.3"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.81+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627211,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 6.7,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "6.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.837+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627212,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 4.3,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "4.3"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.863+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627213,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 5.6,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "5.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.883+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627214,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 7.0,
#             "SpatialDim": "ALB",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.913+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627215,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 1.5,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "1.5"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.943+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627216,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.4,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "3.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.967+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627217,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 4.3,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "4.3"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:40.99+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627218,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.9,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "0.9"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.017+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627219,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 2.8,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "2.8"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.04+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627220,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.6,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "3.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.063+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627221,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.8,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "0.8"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.093+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627222,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 2.7,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "2.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.113+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627223,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.5,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "3.5"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.14+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627224,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.8,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "0.8"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.163+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627225,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 2.7,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "2.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.187+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627226,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.5,
#             "SpatialDim": "ARE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "3.5"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.213+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627227,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.6,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "3.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.243+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627228,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 9.5,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "9.5"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.263+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627229,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 16.2,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2000,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2000-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2000-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2000",
#             "Value": "16.2"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.287+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627230,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.2,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "3.2"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.31+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627231,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 8.6,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "8.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.33+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627232,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 14.4,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "14.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.35+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627233,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.4,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "3.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.38+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627234,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 8.7,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "8.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.403+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627235,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 14.4,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "14.4"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:56:41.433+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19627236,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 3.5,
#             "SpatialDim": "ARG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
# ...
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "11.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.217+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629363,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 20.6,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "20.6"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.24+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629364,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 32.3,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "32.3"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.263+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629365,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 11.1,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "11.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.283+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629366,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 18.9,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "18.9"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.31+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629367,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 28.7,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "28.7"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.333+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629368,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 11.1,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "11.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.357+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629369,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 19.1,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "19.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.38+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629370,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 29.1,
#             "SpatialDim": "ZWE",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "29.1"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.403+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629371,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.0,
#             "SpatialDim": "ATG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "0"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.433+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629372,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.0,
#             "SpatialDim": "ATG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2015,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2015-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2015-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2015",
#             "Value": "0"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.453+02:00",
#             "Dim1": "MLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629373,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.0,
#             "SpatialDim": "ATG",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "0"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T07:57:39.48+02:00",
#             "Dim1": "FMLE",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629374,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 0.0,
#             "SpatialDim": "GRD",
#             "SpatialDimType": "COUNTRY",
#             "TimeDim": 2010,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2010-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2010-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2010",
#             "Value": "0"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.217+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629382,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 10.5328,
#             "SpatialDim": "GLOBAL",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "10.53"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.24+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629383,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 11.95732,
#             "SpatialDim": "AFR",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "11.96"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.263+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629384,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 9.25494,
#             "SpatialDim": "AMR",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "9.25"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.283+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629385,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 13.40347,
#             "SpatialDim": "SEAR",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "13.40"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.303+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629386,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 12.85462,
#             "SpatialDim": "EUR",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "12.85"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.327+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629387,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 4.30386,
#             "SpatialDim": "EMR",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "4.30"
#         },
#         {
#             "Comments": null,
#             "DataSourceDim": null,
#             "DataSourceDimType": null,
#             "Date": "2018-07-17T08:37:08.347+02:00",
#             "Dim1": "BTSX",
#             "Dim1Type": "SEX",
#             "Dim2": null,
#             "Dim2Type": null,
#             "Dim3": null,
#             "Dim3Type": null,
#             "High": null,
#             "Id": 19629388,
#             "IndicatorCode": "MH_12",
#             "Low": null,
#             "NumericValue": 8.44795,
#             "SpatialDim": "WPR",
#             "SpatialDimType": "REGION",
#             "TimeDim": 2016,
#             "TimeDimType": "YEAR",
#             "TimeDimensionBegin": "2016-01-01T00:00:00+01:00",
#             "TimeDimensionEnd": "2016-12-31T00:00:00+01:00",
#             "TimeDimensionValue": "2016",
#             "Value": "8.45"
#         }
#     ]
# }
